# %%
from manim import *
config.media_width="100%"
# Out:
# Manim Community v0.17.3

# %%
    from manim import *
    config.media_width="100%"

# %%
# %%manim-qm MyScene
#
# class MyScene (Scene):
#     def construct(self):
#         circle=Circle()
#         self.play(GrowFromCenter(circle))
#         self.wait()
# Out:
# UsageError: Cell magic `%%manim-qm` not found.

# %%
cls

# %%
# %%manim -v Warning  -qm MyScene
#
# class MyScene (Scene):
#     def construct(self):
#         circle=Circle()
#         self.play(GrowFromCenter(circle))
#         self.wait()
# Out:
# <video src="media\jupyter\MyScene@2023-09-09@09-43-59.mp4" controls autoplay loop style="max-width: 100%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Example(Scene):
    def construct(self):
        sq=Square(color=RED, stroke_width=20)
        sq.set(height=config.frame_height-3)
        self.add(sq)
        
        SCENE_TO_RENDER = Example

# %%
# %%manim -qm Example
# class Example(Scene):
#     def construct(self):
#         sq=Square(color=RED, stroke_width=20)
#         sq.set(height=config.frame_height-3)
#         self.add(sq)
#
#         SCENE_TO_RENDER = Example
# Out:
# [09/09/23 10:53:40] INFO                                                                   ]8;id=120880;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=799378;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\Desktop\Manim\media\images\Manim\Example_Mani
#                              mCE_v0.17.3.png'
#                     INFO     Rendered Example                                                          ]8;id=884151;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=531153;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Example
# class Example(Scene):
#     def construct(self):
#         sq=Square(color=RED, stroke_width=20)
#         sq.set(height=config.frame_height-3)
#         self.add(sq)
#         self.play(growfromcenter(sq))
#
#         SCENE_TO_RENDER = Example
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Adish\Desktop\Manim\notebook.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/Desktop/Manim/notebook.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Example', 'class Example(Scene):\n    def construct(self):\n        sq=Square(color=RED, stroke_width=20)\n        sq.set(height=config.frame_height-3)\n        self.add(sq)\n        self.play(growfromcenter(sq))\n        \n        SCENE_TO_RENDER = Example\n')
#
# File c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:6, in construct(self)
#
# NameError: name 'growfromcenter' is not defined

# %%
# %%manim -qm Example
#
# class Example(Scene):
#     def construct(self):
#         sq=Square(color=RED, stroke_width=20)
#         sq.set(height=config.frame_height-3)
#         self.add(sq)
#         self.play(GrowFromCenter(sq))
#
#         SCENE_TO_RENDER = Example
# Out:
# [09/09/23 10:55:35] INFO     Animation 0 : Partial movie file written in                   ]8;id=386711;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=883908;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\Desktop\Manim\media\videos\Manim\720p30\parti
#                              al_movie_files\Example\274514146_2686968290_3271262296.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=964297;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=639937;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=507487;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=558659;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\Desktop\Manim\media\videos\Manim\720p30\Examp
#                              le.mp4'
#                     INFO     Rendered Example                                                          ]8;id=788533;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=190291;file://c:\Users\Adish\Desktop\Manim\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 1 animations
# <video src="media\jupyter\Example@2023-09-09@10-55-35.mp4" controls autoplay loop style="max-width: 100%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Example
#
# class Example(Scene):
#     def construct(self):
#         circle=Circle()
#         Circle.height=10;
#         circle.color=red;
#         self.add(circle)
#         self.play(GrowFromCenter(circle));
# Out:
# UsageError: Cell magic `%%manim` not found.

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -pqm Intro
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#         self.play(
#             Write(equation)
#         )
#
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         self.wait()
# Out:
# [09/11/23 06:16:10] INFO     Animation 0 : Partial movie file written in                   ]8;id=921103;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=815887;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\274514146_1823073981_223132457.mp4'
# [09/11/23 06:16:12] INFO     Animation 1 : Partial movie file written in                   ]8;id=189018;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=527601;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3623726045_2047478226.mp4
#                              '
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=372420;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=577481;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_549977174.mp4'
# [09/11/23 06:16:13] INFO     Animation 3 : Partial movie file written in                   ]8;id=562883;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=998810;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1248676425_3049270095.mp4
#                              '
#                     INFO     Animation 4 : Partial movie file written in                   ]8;id=80771;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=705171;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3721154580_2109712235.mp4
#                              '
# [09/11/23 06:16:14] INFO     Animation 5 : Partial movie file written in                   ]8;id=162946;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=656430;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3172287411_3339812486.mp4
#                              '
# [09/11/23 06:16:15] INFO     Animation 6 : Partial movie file written in                   ]8;id=433023;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=146642;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_3805602405.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=879583;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=63113;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=348696;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=526695;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=392917;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=522535;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 7 animations
#                     INFO     Previewed File at:                                                     ]8;id=181226;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\file_ops.py\file_ops.py]8;;\:]8;id=915491;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\file_ops.py#227\227]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\Intro.mp4'
# <video src="media\jupyter\Intro@2023-09-11@06-16-15.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Triangle_rendering
#
# class Triangle_rendering(Scene):
#     def construct (self):
#         tri=Triangle()
#         number=NumberPlane()
#         self.add(number)
#         tri.height=4
#         tri.width=5
#
#         self.play(Create(tri))
#         self.play(Rotate(tri,PI))
#         self.wait()
# Out:
# [09/11/23 08:55:31] INFO     Animation 0 : Using cached data (hash :                           ]8;id=458185;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=305798;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_3150807225_2334632305)
# [09/11/23 08:55:32] INFO     Animation 1 : Partial movie file written in                   ]8;id=724066;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=905446;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\2789044632_2037692170_3
#                              044804713.mp4'
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=16871;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=508575;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\2789044632_3315967912_3
#                              989581673.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=401755;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=544046;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=165677;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=709342;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\T
#                              riangle_rendering.mp4'
#                     INFO     Rendered Triangle_rendering                                               ]8;id=889569;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=683715;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 3 animations
# <video src="media\jupyter\Triangle_rendering@2023-09-11@08-55-32.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
# Out:
# [09/11/23 20:30:46] INFO     Animation 0 : Using cached data (hash :                           ]8;id=778000;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=325287;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1823073981_223132457)
# [09/11/23 20:30:47] INFO     Animation 1 : Using cached data (hash :                           ]8;id=145655;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=22270;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3623726045_2047478226)
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=71357;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=541329;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_549977174.mp4'
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=803854;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=259829;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_3049270095)
# [09/11/23 20:30:48] INFO     Animation 4 : Using cached data (hash :                           ]8;id=304370;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=715256;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3721154580_2109712235)
# [09/11/23 20:30:49] INFO     Animation 5 : Partial movie file written in                   ]8;id=865265;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=547049;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_4190124686_3339812486.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=453242;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=271739;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/11/23 20:30:50] INFO                                                                   ]8;id=699486;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=11734;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=527130;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=991040;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 6 animations
# <video src="media\jupyter\Intro@2023-09-11@20-30-50.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Triangle_rendering(Scene):
    def construct(self):
        Tri=Triangle()
        self.play(Create(Tri))
        self.wait()

# %%
# %%manim -qm Triangle_rendering
# class Triangle_rendering(Scene):
#     def construct(self):
#         Tri=Triangle()
#         self.play(Create(Tri))
#         self.wait()
# Out:
# [09/11/23 20:38:16] INFO     Animation 0 : Partial movie file written in                   ]8;id=471437;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=959337;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\274514146_3595692420_22
#                              3132457.mp4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=760613;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=851697;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\2789044632_329969645_26
#                              32546357.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=252921;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=740406;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=761228;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=941896;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\T
#                              riangle_rendering.mp4'
#                     INFO     Rendered Triangle_rendering                                               ]8;id=517583;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=456290;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 2 animations
# <video src="media\jupyter\Triangle_rendering@2023-09-11@20-38-16.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Triangle_rendering
# class Triangle_rendering(Scene):
#     def construct(self):
#         vertices = [
#             np.array([-1, -1, 0]),  # Vertex 1
#             np.array([2, -1, 0]),   # Vertex 2
#             np.array([-1, 2, 0]),   # Vertex 3
#         ]
#
#         # Create a right-angled triangle using the Polygon class
#         triangle = Polygon(*vertices, color=WHITE, fill_opacity=0.5)
#         self.play(Create(triangle))
#         self.wait()
# Out:
# [09/11/23 20:50:27] INFO     Animation 0 : Partial movie file written in                   ]8;id=253927;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=934652;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\274514146_1948106006_22
#                              3132457.mp4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=491900;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=5568;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\2789044632_329969645_25
#                              4083965.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=260230;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=737749;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=590707;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=706865;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\T
#                              riangle_rendering.mp4'
#                     INFO     Rendered Triangle_rendering                                               ]8;id=902769;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=672166;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 2 animations
# <video src="media\jupyter\Triangle_rendering@2023-09-11@20-50-27.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#         self.add(numberplane)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#             np.array([0, 0, 0]),
#         ]
#
#         vertices_tan =[
#             np.array([3/np.cos(angular),(3/np.cos(angular)*np.cos(angular))]),
#             np.array([3/np.cos(angular),0,0]),
#             np.array([0,0,0])
#         ]
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=RED)
#         self.play(Create(triangle_sin,triangle_tan))
#         self.wait()
# Out:
# [09/11/23 21:16:06] INFO     Animation 0 : Using cached data (hash :                           ]8;id=812938;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=491509;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=282553;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=464994;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=660609;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=635782;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=293700;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=755813;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=678964;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=208801;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=629615;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=300276;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_365313117_1659206401)
# [09/11/23 21:16:07] INFO     Animation 6 : Using cached data (hash :                           ]8;id=321459;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=386127;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2668755289)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', '\nclass Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n        self.add(numberplane) \n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([3*np.cos(angular),3*np.sin(angular), 0]), \n            np.array([3*np.cos(angular),0, 0]),  \n            np.array([0, 0, 0]),   \n        ]\n\n        vertices_tan =[\n            np.array([3/np.cos(angular),(3/np.cos(angular)*np.cos(angular))]),\n            np.array([3/np.cos(angular),0,0]),\n            np.array([0,0,0])\n        ]\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=RED)\n        self.play(Create(triangle_sin,triangle_tan))\n        self.wait()\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:39, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\polygram.py:308, in Polygon.__init__(self, *vertices, **kwargs)
#     307 def __init__(self, *vertices: Sequence[float], **kwargs):
# --> 308     super().__init__(vertices, **kwargs)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\polygram.py:75, in Polygram.__init__(self, color, *vertex_groups, **kwargs)
#      72 first_vertex, *vertices = vertices
#      73 first_vertex = np.array(first_vertex)
# ---> 75 self.start_new_path(first_vertex)
#      76 self.add_points_as_corners(
#      77     [*(np.array(vertex) for vertex in vertices), first_vertex],
#      78 )
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\types\vectorized_mobject.py:683, in VMobject.start_new_path(self, point)
#     681     for _ in range(4 - (len(self.points) % 4)):
#     682         self.append_points([last_anchor])
# --> 683 self.append_points([point])
#     684 return self
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\types\vectorized_mobject.py:673, in VMobject.append_points(self, new_points)
#     669 def append_points(self, new_points):
#     670     # TODO, check that number new points is a multiple of 4?
#     671     # or else that if len(self.points) % 4 == 1, then
#     672     # len(new_points) % 4 == 3?
# --> 673     self.points = np.append(self.points, new_points, axis=0)
#     674     return self
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\numpy\lib\function_base.py:5617, in append(arr, values, axis)
#    5615     values = ravel(values)
#    5616     axis = arr.ndim-1
# -> 5617 return concatenate((arr, values), axis=axis)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 3 and the array at index 1 has size 2

# %%
# %%manim -qm Triangle_rendering
# class Triangle_rendering(Scene):
#     def construct(self):
#         vertices = [
#             np.array([-1, -1, 0]),  # Vertex 1
#             np.array([2, -1, 0]),   # Vertex 2
#             np.array([-1, 2, 0]),   # Vertex 3
#         ]
#
#         # Create a right-angled triangle using the Polygon class
#         triangle = RegularPolygon(
#             n=3,
#             start_angle=PI/4
#         )
#         self.play(Create(triangle))
#         self.wait()
# Out:
# Animation 0: Create(RegularPolygon):   0%|          | 0/30 [00:00<?, ?it/s]
# [09/11/23 20:57:05] INFO     Animation 0 : Partial movie file written in                   ]8;id=794311;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=919433;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\274514146_1386245163_22
#                              3132457.mp4'
# [09/11/23 20:57:06] INFO     Animation 1 : Partial movie file written in                   ]8;id=539850;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=429921;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Triangle_rendering\2789044632_329969645_13
#                              23859038.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=308221;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=383095;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=408291;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=799449;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\T
#                              riangle_rendering.mp4'
#                     INFO     Rendered Triangle_rendering                                               ]8;id=610501;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=922804;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 2 animations
# <video src="media\jupyter\Triangle_rendering@2023-09-11@20-57-06.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#         self.add(numberplane)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0])
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0])
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=RED)
#         label_A = Tex("$A$", color=WHITE).next_to(triangle_sin.get_corner(0), DOWN)
#         label_B = Tex("$B$", color=WHITE).next_to(triangle_sin.get_corner(1), DOWN)
#         label_C = Tex("$C$", color=WHITE).next_to(triangle_sin.get_corner(2), UP)
#
#         label_B1 = Tex("$B'$", color=WHITE).next_to(triangle_tan.get_corner(1), DOWN)
#         label_C1 = Tex("$C'$", color=WHITE).next_to(triangle_tan.get_corner(2), UP)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan,run_time=3))
#         self.wait()
# Out:
# [09/11/23 21:37:43] INFO     Animation 0 : Using cached data (hash :                           ]8;id=731284;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=282625;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/11/23 21:37:44] INFO     Animation 1 : Using cached data (hash :                           ]8;id=532589;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=374159;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=957804;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=908131;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=4821;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=104821;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=479749;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=239852;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=352712;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=904772;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_811432457_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=794009;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=904801;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2668755289)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', '\nclass Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n        self.add(numberplane) \n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0])\n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0])\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=RED)\n        label_A = Tex("$A$", color=WHITE).next_to(triangle_sin.get_corner(0), DOWN)\n        label_B = Tex("$B$", color=WHITE).next_to(triangle_sin.get_corner(1), DOWN)\n        label_C = Tex("$C$", color=WHITE).next_to(triangle_sin.get_corner(2), UP)\n\n        label_B1 = Tex("$E$", color=WHITE).next_to(triangle_tan.get_corner(1), DOWN)\n        label_C1 = Tex("$F$", color=WHITE).next_to(triangle_tan.get_corner(2), UP)\n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(triangle_tan,run_time=3))\n        self.wait()\n\n      \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:44, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:1949, in Mobject.get_corner(self, direction)
#    1947 def get_corner(self, direction) -> np.ndarray:
#    1948     """Get corner coordinates for certain direction."""
# -> 1949     return self.get_critical_point(direction)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:1937, in Mobject.get_critical_point(self, direction)
#    1932     return result
#    1933 for dim in range(self.dim):
#    1934     result[dim] = self.get_extremum_along_dim(
#    1935         all_points,
#    1936         dim=dim,
# -> 1937         key=direction[dim],
#    1938     )
#    1939 return result
#
# TypeError: 'int' object is not subscriptable

# %%
# Out:
# [09/11/23 21:38:32] INFO     Animation 0 : Using cached data (hash :                           ]8;id=369295;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=913284;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=652970;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=959476;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=903949;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=152570;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
# [09/11/23 21:38:33] INFO     Animation 3 : Using cached data (hash :                           ]8;id=184611;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=961582;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=361335;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=355753;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=799184;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=513825;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_811432457_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=968799;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=298563;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2668755289)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', '\nclass Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n        self.add(numberplane) \n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0])\n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0])\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=RED)\n        label_A = Tex("$A$", color=WHITE).next_to(triangle_sin.get_corner(0), DOWN)\n        label_B = Tex("$B$", color=WHITE).next_to(triangle_sin.get_corner(1), DOWN)\n        label_C = Tex("$C$", color=WHITE).next_to(triangle_sin.get_corner(2), UP)\n\n        label_B1 = Tex("$B\'$", color=WHITE).next_to(triangle_tan.get_corner(1), DOWN)\n        label_C1 = Tex("$C\'$", color=WHITE).next_to(triangle_tan.get_corner(2), UP)\n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(triangle_tan,run_time=3))\n        self.wait()\n\n      \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:44, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:1949, in Mobject.get_corner(self, direction)
#    1947 def get_corner(self, direction) -> np.ndarray:
#    1948     """Get corner coordinates for certain direction."""
# -> 1949     return self.get_critical_point(direction)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:1937, in Mobject.get_critical_point(self, direction)
#    1932     return result
#    1933 for dim in range(self.dim):
#    1934     result[dim] = self.get_extremum_along_dim(
#    1935         all_points,
#    1936         dim=dim,
# -> 1937         key=direction[dim],
#    1938     )
#    1939 return result
#
# TypeError: 'int' object is not subscriptable

# %%
# %%manim -qm Intro
#
# %%manim -qm Intro
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#         self.add(numberplane)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0])
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0])
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=RED)
#         label_A = (Tex("$A$", color=WHITE).next_to(triangle_sin.get_corner(0), DOWN))
#         label_B = Tex("$B$", color=WHITE).next_to(triangle_sin.get_corner(1), DOWN)
#         label_C = Tex("$C$", color=WHITE).next_to(triangle_sin.get_corner(2), UP)
#
#
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan,run_time=3))
#         self.wait()
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[37], line 1
#     get_ipython().run_cell_magic('manim', '-qm Intro', '\n%%manim -qm Intro\n\nclass Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n        self.add(numberplane) \n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0])\n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0])\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=RED)\n        label_A = Tex("$A$", color=WHITE).next_to(triangle_sin.get_corner(0), DOWN)\n        label_B = Tex("$B$", color=WHITE).next_to(triangle_sin.get_corner(1), DOWN)\n        label_C = Tex("$C$", color=WHITE).next_to(triangle_sin.get_corner(2), UP)\n\n      \n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(triangle_tan,run_time=3))\n        self.wait()\n\n      \n')
#
#   File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493 in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:120 in manim
#     exec(cell, local_ns)
#
#   File <string>:2
#     %%manim -qm Intro
#     ^
# SyntaxError: invalid syntax

# %%
from manim import *

# %%
# %%manim -qm Intro
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#         self.add(numberplane)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0])
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0])
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=RED)
#
#
#
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan,run_time=3))
#
#         self.wait()
# Out:
# [09/11/23 21:46:21] INFO     Animation 0 : Using cached data (hash :                           ]8;id=559220;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=291067;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=10263;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=190080;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=826417;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=747374;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=472302;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=499340;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=472179;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=101161;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=820607;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=652671;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
# [09/11/23 21:46:22] INFO     Animation 6 : Using cached data (hash :                           ]8;id=873786;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=135537;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2668755289)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=94106;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=51413;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_3440206338)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=535670;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=46440;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_4051489374_942563123)
# [09/11/23 21:46:23] INFO     Animation 9 : Partial movie file written in                   ]8;id=353491;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=62904;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_3179106549.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=384059;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=338807;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=841486;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=656488;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=133941;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=348681;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 10 animations
# <video src="media\jupyter\Intro@2023-09-11@21-46-23.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#
#         self.wait()
#         together=VGroup(triangle_sin,circ)
#         self.play(together.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))
#
#
#         self.play(Create(triangle_tan,run_time=3))
# Out:
# [09/11/23 22:03:14] INFO     Animation 0 : Using cached data (hash :                           ]8;id=66547;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=903200;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=774686;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=504840;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=903173;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=437628;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=719938;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=583149;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=243711;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=496608;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=74317;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=297382;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
# [09/11/23 22:03:15] INFO     Animation 6 : Using cached data (hash :                           ]8;id=922798;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=445377;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=944535;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=598817;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=635839;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=8920;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2110476343)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:890, in Scene.compile_animations(self, *args, **kwargs)
#     889 try:
# --> 890     animations.append(prepare_animation(arg))
#     891 except TypeError:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:518, in prepare_animation(anim)
#     516     return anim
# --> 518 raise TypeError(f"Object {anim} cannot be converted to an animation")
#
# TypeError: Object VGroup of 2 submobjects cannot be converted to an animation
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        \n        self.wait()\n        together=VGroup(triangle_sin,circ)\n        self.play(together.move_to(3*LEFT))        \n        self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))\n        \n\n        self.play(Create(triangle_tan,run_time=3))\n       \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:46, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1082, in Scene.play(self, subcaption, subcaption_duration, subcaption_offset, *args, **kwargs)
#    1079     return
#    1081 start_time = self.renderer.time
# -> 1082 self.renderer.play(self, *args, **kwargs)
#    1083 run_time = self.renderer.time - start_time
#    1084 if subcaption:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py:60, in CairoRenderer.play(self, scene, *args, **kwargs)
#      57 self.skip_animations = self._original_skipping_status
#      58 self.update_skipping_status()
# ---> 60 scene.compile_animation_data(*args, **kwargs)
#      62 if self.skip_animations:
#      63     logger.debug(f"Skipping animation {self.num_plays}")
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1186, in Scene.compile_animation_data(self, *animations, **play_kwargs)
#    1183 if len(animations) == 0:
#    1184     raise ValueError("Called Scene.play with no animations")
# -> 1186 self.animations = self.compile_animations(*animations, **play_kwargs)
#    1187 self.add_mobjects_from_animations(self.animations)
#    1189 self.last_t = 0
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:898, in Scene.compile_animations(self, *args, **kwargs)
#     893             raise TypeError(
#     894                 "Passing Mobject methods to Scene.play is no longer"
#     895                 " supported. Use Mobject.animate instead.",
#     896             )
#     897         else:
# --> 898             raise TypeError(
#     899                 f"Unexpected argument {arg} passed to Scene.play().",
#     900             )
#     902 for animation in animations:
#     903     for k, v in kwargs.items():
#
# TypeError: Unexpected argument VGroup of 2 submobjects passed to Scene.play().

# %%
# %%manim -qm Intro
# #Cricle
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#
#         self.wait()
#         together=VGroup(triangle_sin,circ)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))
#
#
#         self.play(Create(triangle_tan,run_time=3))
# Out:
# [09/11/23 22:03:48] INFO     Animation 0 : Using cached data (hash :                           ]8;id=348882;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=142778;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/11/23 22:03:49] INFO     Animation 1 : Using cached data (hash :                           ]8;id=319755;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=892346;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=141480;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=462873;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=440975;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=513250;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=833187;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=597718;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=181709;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=479157;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_811432457_1659206401)
# [09/11/23 22:03:50] INFO     Animation 6 : Using cached data (hash :                           ]8;id=893901;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=932285;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=954741;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=29568;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=364680;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=764855;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2110476343)
# [09/11/23 22:03:51] INFO     Animation 9 : Partial movie file written in                   ]8;id=880591;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=435762;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3982035900_3846617075.mp4
#                              '
#                     INFO     Animation 10 : Partial movie file written in                  ]8;id=521692;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=190872;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3538730352_4207457457.mp4
#                              '
# [09/11/23 22:03:53] INFO     Animation 11 : Partial movie file written in                  ]8;id=464206;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=635267;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_63242619_3219694445.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=416863;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=796491;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=985761;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=94359;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=887011;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=195360;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 12 animations
# <video src="media\jupyter\Intro@2023-09-11@22-03-53.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier)
#         self.play(triangle_sin,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))
#
#
#         self.play(Create(triangle_tan,run_time=3))
# Out:
# [09/11/23 22:06:16] INFO     Animation 0 : Using cached data (hash :                           ]8;id=888366;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=527267;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=790757;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=245099;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=51732;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=830148;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=223715;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=386190;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=334569;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=338345;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/11/23 22:06:17] INFO     Animation 5 : Using cached data (hash :                           ]8;id=37770;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=339596;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Partial movie file written in                   ]8;id=745752;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=801522;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_1488519456.mp4'
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=933900;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=55056;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=575326;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=982780;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2110476343)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:890, in Scene.compile_animations(self, *args, **kwargs)
#     889 try:
# --> 890     animations.append(prepare_animation(arg))
#     891 except TypeError:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:518, in prepare_animation(anim)
#     516     return anim
# --> 518 raise TypeError(f"Object {anim} cannot be converted to an animation")
#
# TypeError: Object Polygon cannot be converted to an animation
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        \n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier)\n        self.play(triangle_sin,triangle_tan)\n        self.play(together.animate.move_to(3*LEFT))        \n        self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))\n        \n\n        self.play(Create(triangle_tan,run_time=3))\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:46, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1082, in Scene.play(self, subcaption, subcaption_duration, subcaption_offset, *args, **kwargs)
#    1079     return
#    1081 start_time = self.renderer.time
# -> 1082 self.renderer.play(self, *args, **kwargs)
#    1083 run_time = self.renderer.time - start_time
#    1084 if subcaption:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py:60, in CairoRenderer.play(self, scene, *args, **kwargs)
#      57 self.skip_animations = self._original_skipping_status
#      58 self.update_skipping_status()
# ---> 60 scene.compile_animation_data(*args, **kwargs)
#      62 if self.skip_animations:
#      63     logger.debug(f"Skipping animation {self.num_plays}")
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1186, in Scene.compile_animation_data(self, *animations, **play_kwargs)
#    1183 if len(animations) == 0:
#    1184     raise ValueError("Called Scene.play with no animations")
# -> 1186 self.animations = self.compile_animations(*animations, **play_kwargs)
#    1187 self.add_mobjects_from_animations(self.animations)
#    1189 self.last_t = 0
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:898, in Scene.compile_animations(self, *args, **kwargs)
#     893             raise TypeError(
#     894                 "Passing Mobject methods to Scene.play is no longer"
#     895                 " supported. Use Mobject.animate instead.",
#     896             )
#     897         else:
# --> 898             raise TypeError(
#     899                 f"Unexpected argument {arg} passed to Scene.play().",
#     900             )
#     902 for animation in animations:
#     903     for k, v in kwargs.items():
#
# TypeError: Unexpected argument Polygon passed to Scene.play().

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier)
#         self.play(Create(triangle_sin,triangle_tan))
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))
#
#
#         self.play(Create(triangle_tan,run_time=3))
# Out:
# [09/11/23 22:06:57] INFO     Animation 0 : Using cached data (hash :                           ]8;id=50375;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=246068;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=524584;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=115187;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=221597;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=948531;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=169646;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=941276;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
# [09/11/23 22:06:58] INFO     Animation 4 : Using cached data (hash :                           ]8;id=762811;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=933288;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=776402;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=497535;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=157778;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=677341;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=58705;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=544664;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=219941;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=343518;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2110476343)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        \n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier)\n        self.play(Create(triangle_sin,triangle_tan))\n        self.play(together.animate.move_to(3*LEFT))        \n        self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))\n        \n\n        self.play(Create(triangle_tan,run_time=3))\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:46, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1082, in Scene.play(self, subcaption, subcaption_duration, subcaption_offset, *args, **kwargs)
#    1079     return
#    1081 start_time = self.renderer.time
# -> 1082 self.renderer.play(self, *args, **kwargs)
#    1083 run_time = self.renderer.time - start_time
#    1084 if subcaption:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py:93, in CairoRenderer.play(self, scene, *args, **kwargs)
#      87 logger.debug(
#      88     "List of the first few animation hashes of the scene: %(h)s",
#      89     {"h": str(self.animations_hashes[:5])},
#      90 )
#      92 self.file_writer.begin_animation(not self.skip_animations)
# ---> 93 scene.begin_animations()
#      95 # Save a static image, to avoid rendering non moving objects.
#      96 self.save_static_frame_data(scene, scene.static_mobjects)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1210, in Scene.begin_animations(self)
#    1208 for animation in self.animations:
#    1209     animation._setup_scene(self)
# -> 1210     animation.begin()
#    1212 if config.renderer == RendererType.CAIRO:
#    1213     # Paint all non-moving objects onto the screen, so they don't
#    1214     # have to be rendered every frame
#    1215     (
#    1216         self.moving_mobjects,
#    1217         self.static_mobjects,
#    1218     ) = self.get_moving_and_static_mobjects(self.animations)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:203, in Animation.begin(self)
#     195 if self.suspend_mobject_updating:
#     196     # All calls to self.mobject's internal updaters
#     197     # during the animation, either from this Animation
#    (...)
#     200     # the internal updaters of self.starting_mobject,
#     201     # or any others among self.get_all_mobjects()
#     202     self.mobject.suspend_updating()
# --> 203 self.interpolate(0)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:323, in Animation.interpolate(self, alpha)
#     312 def interpolate(self, alpha: float) -> None:
#     313     """Set the animation progress.
#     314
#     315     This method gets called for every frame during an animation.
#    (...)
#     321         the end.
#     322     """
# --> 323     self.interpolate_mobject(alpha)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:337, in Animation.interpolate_mobject(self, alpha)
#     335 families = list(self.get_all_families_zipped())
#     336 for i, mobs in enumerate(families):
# --> 337     sub_alpha = self.get_sub_alpha(alpha, i, len(families))
#     338     self.interpolate_submobject(*mobs, sub_alpha)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:371, in Animation.get_sub_alpha(self, alpha, index, num_submobjects)
#     367 # TODO, make this more understandable, and/or combine
#     368 # its functionality with AnimationGroup's method
#     369 # build_animations_with_timings
#     370 lag_ratio = self.lag_ratio
# --> 371 full_length = (num_submobjects - 1) * lag_ratio + 1
#     372 value = alpha * full_length
#     373 lower = index * lag_ratio
#
# TypeError: unsupported operand type(s) for *: 'int' and 'Polygon'

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier)
#         self.play(Create(triangle_sin,triangle_tan))
# Out:
# [09/11/23 22:08:57] INFO     Animation 0 : Using cached data (hash :                           ]8;id=158377;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=924630;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=572642;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=991350;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=614690;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=748794;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=195933;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=318259;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=535008;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=538563;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/11/23 22:08:58] INFO     Animation 5 : Using cached data (hash :                           ]8;id=939784;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=935826;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=347360;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=762527;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=730107;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=745378;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=822090;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=787262;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2110476343)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        \n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier)\n        self.play(Create(triangle_sin,triangle_tan))\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:46, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1082, in Scene.play(self, subcaption, subcaption_duration, subcaption_offset, *args, **kwargs)
#    1079     return
#    1081 start_time = self.renderer.time
# -> 1082 self.renderer.play(self, *args, **kwargs)
#    1083 run_time = self.renderer.time - start_time
#    1084 if subcaption:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py:93, in CairoRenderer.play(self, scene, *args, **kwargs)
#      87 logger.debug(
#      88     "List of the first few animation hashes of the scene: %(h)s",
#      89     {"h": str(self.animations_hashes[:5])},
#      90 )
#      92 self.file_writer.begin_animation(not self.skip_animations)
# ---> 93 scene.begin_animations()
#      95 # Save a static image, to avoid rendering non moving objects.
#      96 self.save_static_frame_data(scene, scene.static_mobjects)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1210, in Scene.begin_animations(self)
#    1208 for animation in self.animations:
#    1209     animation._setup_scene(self)
# -> 1210     animation.begin()
#    1212 if config.renderer == RendererType.CAIRO:
#    1213     # Paint all non-moving objects onto the screen, so they don't
#    1214     # have to be rendered every frame
#    1215     (
#    1216         self.moving_mobjects,
#    1217         self.static_mobjects,
#    1218     ) = self.get_moving_and_static_mobjects(self.animations)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:203, in Animation.begin(self)
#     195 if self.suspend_mobject_updating:
#     196     # All calls to self.mobject's internal updaters
#     197     # during the animation, either from this Animation
#    (...)
#     200     # the internal updaters of self.starting_mobject,
#     201     # or any others among self.get_all_mobjects()
#     202     self.mobject.suspend_updating()
# --> 203 self.interpolate(0)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:323, in Animation.interpolate(self, alpha)
#     312 def interpolate(self, alpha: float) -> None:
#     313     """Set the animation progress.
#     314
#     315     This method gets called for every frame during an animation.
#    (...)
#     321         the end.
#     322     """
# --> 323     self.interpolate_mobject(alpha)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:337, in Animation.interpolate_mobject(self, alpha)
#     335 families = list(self.get_all_families_zipped())
#     336 for i, mobs in enumerate(families):
# --> 337     sub_alpha = self.get_sub_alpha(alpha, i, len(families))
#     338     self.interpolate_submobject(*mobs, sub_alpha)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:371, in Animation.get_sub_alpha(self, alpha, index, num_submobjects)
#     367 # TODO, make this more understandable, and/or combine
#     368 # its functionality with AnimationGroup's method
#     369 # build_animations_with_timings
#     370 lag_ratio = self.lag_ratio
# --> 371 full_length = (num_submobjects - 1) * lag_ratio + 1
#     372 value = alpha * full_length
#     373 lower = index * lag_ratio
#
# TypeError: unsupported operand type(s) for *: 'int' and 'Polygon'

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#
#         self.wait()
#         self.play(Create(triangle_sin,triangle_tan))
# Out:
# [09/11/23 22:09:37] INFO     Animation 0 : Using cached data (hash :                           ]8;id=739054;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=376805;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/11/23 22:09:38] INFO     Animation 1 : Using cached data (hash :                           ]8;id=321043;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=581248;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=843354;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=771039;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=796456;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=104029;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=365064;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=518785;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=162087;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=878293;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=464142;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=634458;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
# [09/11/23 22:09:39] INFO     Animation 7 : Using cached data (hash :                           ]8;id=661591;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=4093;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=240771;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=434637;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2110476343)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n     \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        \n        self.wait()\n        self.play(Create(triangle_sin,triangle_tan))\n        \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:45, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1082, in Scene.play(self, subcaption, subcaption_duration, subcaption_offset, *args, **kwargs)
#    1079     return
#    1081 start_time = self.renderer.time
# -> 1082 self.renderer.play(self, *args, **kwargs)
#    1083 run_time = self.renderer.time - start_time
#    1084 if subcaption:
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py:93, in CairoRenderer.play(self, scene, *args, **kwargs)
#      87 logger.debug(
#      88     "List of the first few animation hashes of the scene: %(h)s",
#      89     {"h": str(self.animations_hashes[:5])},
#      90 )
#      92 self.file_writer.begin_animation(not self.skip_animations)
# ---> 93 scene.begin_animations()
#      95 # Save a static image, to avoid rendering non moving objects.
#      96 self.save_static_frame_data(scene, scene.static_mobjects)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:1210, in Scene.begin_animations(self)
#    1208 for animation in self.animations:
#    1209     animation._setup_scene(self)
# -> 1210     animation.begin()
#    1212 if config.renderer == RendererType.CAIRO:
#    1213     # Paint all non-moving objects onto the screen, so they don't
#    1214     # have to be rendered every frame
#    1215     (
#    1216         self.moving_mobjects,
#    1217         self.static_mobjects,
#    1218     ) = self.get_moving_and_static_mobjects(self.animations)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:203, in Animation.begin(self)
#     195 if self.suspend_mobject_updating:
#     196     # All calls to self.mobject's internal updaters
#     197     # during the animation, either from this Animation
#    (...)
#     200     # the internal updaters of self.starting_mobject,
#     201     # or any others among self.get_all_mobjects()
#     202     self.mobject.suspend_updating()
# --> 203 self.interpolate(0)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:323, in Animation.interpolate(self, alpha)
#     312 def interpolate(self, alpha: float) -> None:
#     313     """Set the animation progress.
#     314
#     315     This method gets called for every frame during an animation.
#    (...)
#     321         the end.
#     322     """
# --> 323     self.interpolate_mobject(alpha)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:337, in Animation.interpolate_mobject(self, alpha)
#     335 families = list(self.get_all_families_zipped())
#     336 for i, mobs in enumerate(families):
# --> 337     sub_alpha = self.get_sub_alpha(alpha, i, len(families))
#     338     self.interpolate_submobject(*mobs, sub_alpha)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\animation\animation.py:371, in Animation.get_sub_alpha(self, alpha, index, num_submobjects)
#     367 # TODO, make this more understandable, and/or combine
#     368 # its functionality with AnimationGroup's method
#     369 # build_animations_with_timings
#     370 lag_ratio = self.lag_ratio
# --> 371 full_length = (num_submobjects - 1) * lag_ratio + 1
#     372 value = alpha * full_length
#     373 lower = index * lag_ratio
#
# TypeError: unsupported operand type(s) for *: 'int' and 'Polygon'

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+3*UP)))
#         self.wait()
# Out:
# [09/11/23 22:10:51] INFO     Animation 0 : Using cached data (hash :                           ]8;id=650687;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=520277;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=437618;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=354208;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/11/23 22:10:52] INFO     Animation 2 : Using cached data (hash :                           ]8;id=236984;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=505763;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=56009;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=2603;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=860357;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=976143;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=310941;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=530058;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=85518;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=586768;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=586619;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=319397;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
# [09/11/23 22:10:53] INFO     Animation 8 : Using cached data (hash :                           ]8;id=23158;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=622266;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_425728623_4237364608)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=169035;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=846687;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1764464809)
# [09/11/23 22:10:54] INFO     Animation 10 : Partial movie file written in                  ]8;id=386462;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=543684;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2443189768_386432681.mp4'
#                     INFO     Animation 11 : Partial movie file written in                  ]8;id=839006;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=128177;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3538730352_2584760081.mp4'
# [09/11/23 22:10:55] INFO     Animation 12 : Partial movie file written in                  ]8;id=596701;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=326758;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_3039908929.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=815207;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=247972;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=11886;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=274862;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=372015;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=225595;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 13 animations
# <video src="media\jupyter\Intro@2023-09-11@22-10-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/11/23 22:11:51] INFO     Animation 0 : Using cached data (hash :                           ]8;id=912472;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=151816;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=176873;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=585877;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/11/23 22:11:52] INFO     Animation 2 : Using cached data (hash :                           ]8;id=614782;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=148941;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=561874;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=153513;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=636886;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=49850;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=906557;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=446529;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=524654;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=597886;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=332949;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=880276;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
# [09/11/23 22:11:53] INFO     Animation 8 : Using cached data (hash :                           ]8;id=699820;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=882317;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_425728623_4237364608)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=472615;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=325274;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1764464809)
# [09/11/23 22:11:54] INFO     Animation 10 : Partial movie file written in                  ]8;id=604497;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=191402;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_335370808_515125311.mp4'
# [09/11/23 22:11:55] INFO     Animation 11 : Partial movie file written in                  ]8;id=825876;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=473396;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_549857011_361364195.mp4'
#                     INFO     Animation 12 : Partial movie file written in                  ]8;id=900903;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=805376;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_1583234594.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=668075;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=628172;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/11/23 22:11:56] INFO                                                                   ]8;id=70197;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=909453;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=853488;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=631314;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 13 animations
# <video src="media\jupyter\Intro@2023-09-11@22-11-56.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((triangle_sin.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:13:57] INFO     Animation 0 : Using cached data (hash :                           ]8;id=772712;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=692720;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1823073981_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=541450;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=775201;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3623726045_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=427030;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=264166;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_549977174)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=983268;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=950598;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_3049270095)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=242277;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=780474;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3721154580_2109712235)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=998979;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=506762;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_4190124686_3339812486)
# [09/12/23 06:13:58] INFO     Animation 6 : Partial movie file written in                   ]8;id=554586;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=886852;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_3805602405.mp4'
# [09/12/23 06:14:00] INFO     Animation 7 : Partial movie file written in                   ]8;id=670385;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=818582;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_71954140_4028234169.mp4'
# [09/12/23 06:14:01] INFO     Animation 8 : Partial movie file written in                   ]8;id=871295;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=768750;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_315134564_3466501480.mp4'
#                     INFO     Animation 9 : Partial movie file written in                   ]8;id=443714;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=118650;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_3888890220.mp4'
# [09/12/23 06:14:02] INFO     Animation 10 : Partial movie file written in                  ]8;id=420305;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=554824;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_4269948024_1260654811.mp4
#                              '
# [09/12/23 06:14:03] INFO     Animation 11 : Partial movie file written in                  ]8;id=176370;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=549878;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_549857011_2349612098.mp4'
# [09/12/23 06:14:04] INFO     Animation 12 : Partial movie file written in                  ]8;id=128792;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=352383;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_1484135685.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=95222;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=494271;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=375739;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=187095;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=916347;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=416028;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 13 animations
# <video src="media\jupyter\Intro@2023-09-12@06-14-04.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=3*np.cos(angular))
#         vertices_sin_b=Line(start=3*np.cos(angular),end=3*np.sin(angular))
#         vertices_sin_c=Line(start=3*np.sin(angular,end=[0,0,0]))
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.appear(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:22:56] INFO     Animation 0 : Using cached data (hash :                           ]8;id=844181;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=282774;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=160028;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=154307;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=467687;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=130239;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=428415;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=556275;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=934455;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=212619;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=240654;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=809217;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
# [09/12/23 06:22:57] INFO     Animation 6 : Using cached data (hash :                           ]8;id=797249;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=396161;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        vertices_sin_a=Line(start=[0,0,0], end=3*np.cos(angular))\n        vertices_sin_b=Line(start=3*np.cos(angular),end=3*np.sin(angular))\n        vertices_sin_c=Line(start=3*np.sin(angular,end=[0,0,0]))\n\n        lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)\n\n\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n        \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(triangle_tan),run_time=3)\n        self.appear(lines)\n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)\n        self.play(together.animate.move_to(3*LEFT))        \n        self.play((lines.animate.move_to(5*RIGHT+2*UP)))\n        self.wait()        \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:30, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\line.py:41, in Line.__init__(self, start, end, buff, path_arc, **kwargs)
#      39 self.path_arc = path_arc
#      40 self._set_start_and_end_attrs(start, end)
# ---> 41 super().__init__(**kwargs)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\arc.py:100, in TipableVMobject.__init__(self, tip_length, normal_vector, tip_style, **kwargs)
#      98 self.normal_vector = normal_vector
#      99 self.tip_style = tip_style
# --> 100 super().__init__(**kwargs)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\types\vectorized_mobject.py:125, in VMobject.__init__(self, fill_color, fill_opacity, stroke_color, stroke_opacity, stroke_width, background_stroke_color, background_stroke_opacity, background_stroke_width, sheen_factor, joint_type, sheen_direction, close_new_points, pre_function_handle_to_anchor_scale_factor, make_smooth_after_applying_functions, background_image, shade_in_3d, tolerance_for_point_equality, n_points_per_cubic_curve, **kwargs)
#     123 self.tolerance_for_point_equality = tolerance_for_point_equality
#     124 self.n_points_per_cubic_curve = n_points_per_cubic_curve
# --> 125 super().__init__(**kwargs)
#     127 if fill_color:
#     128     self.fill_color = fill_color
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:106, in Mobject.__init__(self, color, name, dim, target, z_index)
#     103 self.color = Color(color) if color else None
#     105 self.reset_points()
# --> 106 self.generate_points()
#     107 self.init_colors()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\line.py:44, in Line.generate_points(self)
#      43 def generate_points(self):
# ---> 44     self.set_points_by_ends(
#      45         start=self.start,
#      46         end=self.end,
#      47         buff=self.buff,
#      48         path_arc=self.path_arc,
#      49     )
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\line.py:56, in Line.set_points_by_ends(self, start, end, buff, path_arc)
#      54     self.set_points(arc.points)
#      55 else:
# ---> 56     self.set_points_as_corners([start, end])
#      58 self._account_for_buff(buff)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\types\vectorized_mobject.py:861, in VMobject.set_points_as_corners(self, points)
#     845 """Given an array of points, set them as corner of the vmobject.
#     846
#     847 To achieve that, this algorithm sets handles aligned with the anchors such that the resultant bezier curve will be the segment
#    (...)
#     858     ``self``
#     859 """
#     860 nppcc = self.n_points_per_cubic_curve
# --> 861 points = np.array(points)
#     862 # This will set the handles aligned with the anchors.
#     863 # Id est, a bezier curve will be the segment from the two anchors such that the handles belongs to this segment.
#     864 self.set_anchors_and_handles(
#     865     *(interpolate(points[:-1], points[1:], a) for a in np.linspace(0, 1, nppcc))
#     866 )
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin[angular,0,0], end=[0,0,0]))
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.appear(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 1
#     get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])\n        vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])\n        vertices_sin_c=Line(start=[3*np.sin[angular,0,0], end=[0,0,0]))\n\n        lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)\n\n\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([3,0,0]),\n          \n        ]\n\n        \n\n        triangle_sin = Polygon(*vertices_sin, color=WHITE)\n        triangle_tan = Polygon(*vertices_tan, color=WHITE)\n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(triangle_tan),run_time=3)\n        self.appear(lines)\n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)\n        self.play(together.animate.move_to(3*LEFT))        \n        self.play((lines.animate.move_to(5*RIGHT+2*UP)))\n        self.wait()        \n')
#
#   File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493 in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:120 in manim
#     exec(cell, local_ns)
#
#   File <string>:32
#     vertices_sin_c=Line(start=[3*np.sin[angular,0,0], end=[0,0,0]))
#                         ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#
#         triangle_sin = Polygon(*vertices_sin, color=WHITE)
#         triangle_tan = Polygon(*vertices_tan, color=WHITE)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:28:54] INFO     Animation 0 : Using cached data (hash :                           ]8;id=343090;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=212549;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/12/23 06:28:55] INFO     Animation 1 : Using cached data (hash :                           ]8;id=454841;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=77347;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=653562;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=870233;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=198030;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=262455;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=348735;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=157084;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=804372;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=223452;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=823204;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=573958;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
# [09/12/23 06:28:56] INFO     Animation 7 : Using cached data (hash :                           ]8;id=385553;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=404397;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_266430167_2862630327)
# [09/12/23 06:28:57] INFO     Animation 8 : Partial movie file written in                   ]8;id=168516;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=317663;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3446566490_4237364608.mp4
#                              '
#                     INFO     Animation 9 : Partial movie file written in                   ]8;id=964722;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=792102;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2475698917.mp4
#                              '
# [09/12/23 06:28:58] INFO     Animation 10 : Partial movie file written in                  ]8;id=666920;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=322084;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_864366050_3061663668.mp4'
# [09/12/23 06:28:59] INFO     Animation 11 : Partial movie file written in                  ]8;id=828799;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=860088;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_296542241_670637933.mp4'
# [09/12/23 06:29:00] INFO     Animation 12 : Partial movie file written in                  ]8;id=572662;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=615564;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2029240714.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=427264;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=404589;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=135521;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=803898;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=740886;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=965885;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 13 animations
# <video src="media\jupyter\Intro@2023-09-12@06-29-00.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:35:38] INFO     Animation 0 : Using cached data (hash :                           ]8;id=277387;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=93860;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=778004;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=636320;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=86095;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=575986;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=508823;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=542998;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=673056;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=48305;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/12/23 06:35:39] INFO     Animation 5 : Using cached data (hash :                           ]8;id=994268;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=642907;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=758074;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=983152;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Partial movie file written in                   ]8;id=215059;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=242858;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_784930149_3546483927.mp4'
# [09/12/23 06:35:41] INFO     Animation 8 : Partial movie file written in                   ]8;id=522559;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=497892;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_1163585900_2879665698.mp4'
# [09/12/23 06:35:42] INFO     Animation 9 : Partial movie file written in                   ]8;id=523885;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=86315;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2051165797_3454062966.mp4
#                              '
# [09/12/23 06:35:43] INFO     Animation 10 : Partial movie file written in                  ]8;id=124217;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=345697;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_776998308.mp4'
# [09/12/23 06:35:44] INFO     Animation 11 : Partial movie file written in                  ]8;id=596076;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=32689;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3570649153_3061663668.mp4
#                              '
#                     INFO     Animation 12 : Partial movie file written in                  ]8;id=598746;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=524041;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2767085067.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=872369;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=499093;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=78522;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=168082;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=543742;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=170892;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 1 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=159542;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=572699;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 13 animations
# <video src="media\jupyter\Intro@2023-09-12@06-35-44.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(triangle_tan),run_time=3)
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,radius_text)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:36:57] INFO     Animation 0 : Using cached data (hash :                           ]8;id=621404;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=94230;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=647916;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=546354;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/12/23 06:36:58] INFO     Animation 2 : Using cached data (hash :                           ]8;id=279373;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=131833;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=369936;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=899937;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=973525;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=718252;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=81313;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=982347;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=279067;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=869640;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=69509;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=476453;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
# [09/12/23 06:37:00] INFO     Animation 8 : Partial movie file written in                   ]8;id=769896;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=290451;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_205815995_2879665698.mp4'
# [09/12/23 06:37:01] INFO     Animation 9 : Partial movie file written in                   ]8;id=410970;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=131259;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1731054582_3454062966.mp4
#                              '
# [09/12/23 06:37:02] INFO     Animation 10 : Partial movie file written in                  ]8;id=219747;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=157204;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_3024804521.mp4'
# [09/12/23 06:37:03] INFO     Animation 11 : Partial movie file written in                  ]8;id=561818;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=912386;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3570649153_515125311.mp4'
#                     INFO     Animation 12 : Partial movie file written in                  ]8;id=251042;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=760715;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_2251628949.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=996263;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=912052;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=895737;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=118497;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=890175;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=438152;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 5 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=624331;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=967614;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 13 animations
# <video src="media\jupyter\Intro@2023-09-12@06-37-03.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         alpha_signifier=Arc(radius=0.3, start_angle=angular)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(Arc.next_to([0,0,0],UP)))
#         self.play(Create(triangle_tan),run_time=3)
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:41:44] INFO     Animation 0 : Using cached data (hash :                           ]8;id=202791;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=935829;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/12/23 06:41:45] INFO     Animation 1 : Using cached data (hash :                           ]8;id=811048;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=697469;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=229468;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=92461;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=383349;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=254818;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=621767;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=421131;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=396190;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=229093;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=453237;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=300263;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=323670;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=134830;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
# [09/12/23 06:41:46] INFO     Animation 8 : Using cached data (hash :                           ]8;id=509605;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=909198;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              207390714_1163585900_2879665698)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 42 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])\n        vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])\n        vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])\n\n        lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)\n\n\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([-3,0,0]),\n          \n        ]\n        \n        \n        self.play(FadeOut(radius_text))\n        triangle_sin = Polygon(*vertices_sin, color=BLUE)\n        triangle_tan = Polygon(*vertices_tan, color=GREEN)\n        alpha_signifier=Arc(radius=0.3, start_angle=angular)\n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(Arc.next_to([0,0,0],UP)))\n        self.play(Create(triangle_tan),run_time=3)\n        # self.add(lines)\n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)\n        self.play(together.animate.move_to(3*LEFT))        \n        # self.play((lines.animate.move_to(5*RIGHT+2*UP)))\n        self.wait()        \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:51, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:1445, in Mobject.next_to(self, mobject_or_point, direction, buff, aligned_edge, submobject_to_align, index_of_submobject_to_align, coor_mask)
#    1443 else:
#    1444     aligner = self
# -> 1445 point_to_align = aligner.get_critical_point(aligned_edge - direction)
#    1446 self.shift((target_point - point_to_align + buff * direction) * coor_mask)
#    1447 return self
#
# AttributeError: 'list' object has no attribute 'get_critical_point'

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         alpha_signifier=Arc(radius=0.3, start_angle=angular)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(Arc.next_to([0,0,0],UP)))
#         self.play(Create(triangle_tan),run_time=3)
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:42:40] INFO     Animation 0 : Using cached data (hash :                           ]8;id=322619;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=831763;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=249873;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=426677;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/12/23 06:42:41] INFO     Animation 2 : Using cached data (hash :                           ]8;id=767428;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=85376;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=666624;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=772287;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=360041;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=838313;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=301592;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=877926;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=87674;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=386032;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=400284;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=367686;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=836500;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=881491;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 43 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', 'class Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n        \n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)\n\n        # chaine kura ho\n        self.wait()\n        \n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular=PI/180 *25\n        vertices_sin = [\n            np.array([0, 0, 0]), \n            np.array([3*np.cos(angular),3*np.sin(angular), 0]),  \n            np.array([3*np.cos(angular),0, 0]), \n        ]\n        vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])\n        vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])\n        vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])\n\n        lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)\n\n\n        radius_tan=3/np.cos(angular)\n        vertices_tan =[\n            np.array([0,0,0]),\n            np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),\n            np.array([-3,0,0]),\n          \n        ]\n        \n        \n        self.play(FadeOut(radius_text))\n        triangle_sin = Polygon(*vertices_sin, color=BLUE)\n        triangle_tan = Polygon(*vertices_tan, color=GREEN)\n        alpha_signifier=Arc(radius=0.3, start_angle=angular)\n        self.play(Create(triangle_sin),run_time=3)\n        self.play(Create(Arc.next_to([0,0,0],UP)))\n        self.play(Create(triangle_tan),run_time=3)\n        # self.add(lines)\n        self.wait()\n        together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)\n        self.play(together.animate.move_to(3*LEFT))        \n        # self.play((lines.animate.move_to(5*RIGHT+2*UP)))\n        self.wait()     \n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:51, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\mobject.py:1445, in Mobject.next_to(self, mobject_or_point, direction, buff, aligned_edge, submobject_to_align, index_of_submobject_to_align, coor_mask)
#    1443 else:
#    1444     aligner = self
# -> 1445 point_to_align = aligner.get_critical_point(aligned_edge - direction)
#    1446 self.shift((target_point - point_to_align + buff * direction) * coor_mask)
#    1447 return self
#
# AttributeError: 'list' object has no attribute 'get_critical_point'

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         alpha_signifier=Arc(radius=0.3, start_angle=angular)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier.next_to(vertices_sin_a,UP)))
#         self.play(Create(triangle_tan),run_time=3)
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:45:01] INFO     Animation 0 : Using cached data (hash :                           ]8;id=390400;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=713099;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=326918;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=96521;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=505268;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=874358;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=414346;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=626312;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=580718;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=284451;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=817119;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=855908;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=595850;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=823525;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
# [09/12/23 06:45:02] INFO     Animation 7 : Using cached data (hash :                           ]8;id=683505;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=671272;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=596504;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=644537;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Partial movie file written in                   ]8;id=543876;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=553370;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1800498629_3936732207.mp4
#                              '
# [09/12/23 06:45:04] INFO     Animation 10 : Partial movie file written in                  ]8;id=795298;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=807949;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2051165797_3282018405.mp4
#                              '
#                     INFO     Animation 11 : Partial movie file written in                  ]8;id=307760;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=109809;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_3643885771.mp4'
# [09/12/23 06:45:05] INFO     Animation 12 : Partial movie file written in                  ]8;id=163195;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=63173;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_634088727_2548752054.mp4'
# [09/12/23 06:45:06] INFO     Animation 13 : Partial movie file written in                  ]8;id=344973;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=445822;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2467323794.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=796358;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=399740;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=902256;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=364510;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=383145;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=47591;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 5 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=727813;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=466763;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 14 animations
# <video src="media\jupyter\Intro@2023-09-12@06-45-06.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         self.add(numberplane)
#         alpha_signifier=ArcBetweenPoints(start=[0,0,0],end=[0,0.5,0],angle=angular,radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier.next_to(vertices_sin_a,UP)))
#         self.play(Create(triangle_tan),run_time=3)
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:47:21] INFO     Animation 0 : Using cached data (hash :                           ]8;id=7667;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=498363;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/12/23 06:47:22] INFO     Animation 1 : Using cached data (hash :                           ]8;id=453258;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=56052;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=613404;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=253038;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=548588;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=706549;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=713181;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=159447;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=89307;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=299216;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=855914;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=453221;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              207390714_3315967912_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=6712;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=47863;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
# [09/12/23 06:47:24] INFO     Animation 8 : Partial movie file written in                   ]8;id=28930;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=305199;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_205815995_3826465023.mp4'
# [09/12/23 06:47:25] INFO     Animation 9 : Partial movie file written in                   ]8;id=672353;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=625228;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1354478078_804259687.mp4'
# [09/12/23 06:47:26] INFO     Animation 10 : Partial movie file written in                  ]8;id=378002;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=563951;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2051165797_1586543620.mp4
#                              '
# [09/12/23 06:47:27] INFO     Animation 11 : Partial movie file written in                  ]8;id=724979;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=206202;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_331085593.mp4'
# [09/12/23 06:47:28] INFO     Animation 12 : Partial movie file written in                  ]8;id=812097;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=943796;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_634088727_2115101467.mp4'
#                     INFO     Animation 13 : Partial movie file written in                  ]8;id=792808;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=70556;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_3191595462.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=569515;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=231684;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/12/23 06:47:29] INFO                                                                   ]8;id=509109;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=188787;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=983838;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=273142;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 6 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=218858;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=639384;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 14 animations
# <video src="media\jupyter\Intro@2023-09-12@06-47-29.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         self.add(numberplane)
#         alpha_signifier=ArcBetweenPoints(start=[0.5,0,0],end=[0.40,np.tan(angular)*0.5,0],angle=angular,radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier.next_to(vertices_sin_a,UP)))
#         self.play(Create(triangle_tan),run_time=3)
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:50:06] INFO     Animation 0 : Using cached data (hash :                           ]8;id=504075;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=459440;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=308168;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=156704;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/12/23 06:50:07] INFO     Animation 2 : Using cached data (hash :                           ]8;id=144418;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=569050;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=680620;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=226457;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=652794;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=255766;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=199362;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=301381;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
# [09/12/23 06:50:08] INFO     Animation 6 : Using cached data (hash :                           ]8;id=214909;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=142801;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=932391;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=123724;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=796385;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=704089;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_3826465023)
# [09/12/23 06:50:09] INFO     Animation 9 : Partial movie file written in                   ]8;id=877737;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=281014;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1601345697_804259687.mp4'
# [09/12/23 06:50:11] INFO     Animation 10 : Partial movie file written in                  ]8;id=453925;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=697034;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1731054582_937241700.mp4'
#                     INFO     Animation 11 : Partial movie file written in                  ]8;id=45717;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=361088;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2933117578.mp4
#                              '
# [09/12/23 06:50:13] INFO     Animation 12 : Partial movie file written in                  ]8;id=643203;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=774696;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_634088727_3390250791.mp4'
#                     INFO     Animation 13 : Partial movie file written in                  ]8;id=372830;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=839770;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_1174462893.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=121771;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=826682;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=427475;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=773570;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
# [09/12/23 06:50:14] INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=646882;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=24438;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 5 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=729480;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=898721;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 14 animations
# <video src="media\jupyter\Intro@2023-09-12@06-50-14.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#         self.add(numberplane)
#         alpha_signifier=ArcBetweenPoints(start=[0.5,0,0],end=[0.40,np.tan(angular)*0.5,0],angle=angular,radius=0.3)
#         theta_signifier=ArcBetweenPoints(start=[-0.5,0,0],end=[-0.40,-np.tan(angular)*0.5,0],angle=angular, radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan),run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 06:52:34] INFO     Animation 0 : Using cached data (hash :                           ]8;id=560987;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=259133;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=945850;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=796905;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/12/23 06:52:35] INFO     Animation 2 : Using cached data (hash :                           ]8;id=990192;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=48272;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=829186;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=883574;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=771405;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=305838;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=148160;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=450422;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=981836;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=125752;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
# [09/12/23 06:52:36] INFO     Animation 7 : Using cached data (hash :                           ]8;id=11633;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=114937;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=332874;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=574546;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_3826465023)
# [09/12/23 06:52:37] INFO     Animation 9 : Partial movie file written in                   ]8;id=62194;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=634485;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_947373812_804259687.mp4'
# [09/12/23 06:52:39] INFO     Animation 10 : Partial movie file written in                  ]8;id=861152;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=638896;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1731054582_4022973951.mp4
#                              '
#                     INFO     Animation 11 : Partial movie file written in                  ]8;id=175124;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=970670;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3421625761_2969163494.mp4
#                              '
# [09/12/23 06:52:40] INFO     Animation 12 : Partial movie file written in                  ]8;id=462650;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=405867;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2900158326.mp4
#                              '
# [09/12/23 06:52:41] INFO     Animation 13 : Partial movie file written in                  ]8;id=505000;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=835218;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_634088727_2281042776.mp4'
# [09/12/23 06:52:42] INFO     Animation 14 : Partial movie file written in                  ]8;id=597606;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=256730;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_3135749541.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=576075;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=683262;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=550612;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=527025;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=284253;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=458303;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 6 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=320278;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=714910;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@06-52-42.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier=ArcBetweenPoints(start=[0.5,0,0],end=[0.50,np.tan(angular)*0.5,0],angle=angular,radius=0.3)
#         theta_signifier=ArcBetweenPoints(start=[-0.5,0,0],end=[-0.50,np.tan(angular)*0.5,0],angle=angular, radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan),run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#         # duplicate both
# Out:
# [09/12/23 06:53:56] INFO     Animation 0 : Using cached data (hash :                           ]8;id=909817;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=407998;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=732198;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=984806;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=792131;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=433233;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=382876;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=46677;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=722749;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=398511;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/12/23 06:53:57] INFO     Animation 5 : Using cached data (hash :                           ]8;id=442637;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=152198;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=292626;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=559538;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=11943;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=184601;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=752694;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=386281;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
# [09/12/23 06:53:58] INFO     Animation 9 : Partial movie file written in                   ]8;id=981943;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=191175;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2033897173_3936732207.mp4
#                              '
# [09/12/23 06:54:00] INFO     Animation 10 : Partial movie file written in                  ]8;id=19967;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=573855;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2051165797_3080706144.mp4
#                              '
#                     INFO     Animation 11 : Partial movie file written in                  ]8;id=930132;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=677454;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3664981868_2100960209.mp4
#                              '
# [09/12/23 06:54:01] INFO     Animation 12 : Partial movie file written in                  ]8;id=802217;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=743321;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_2086748044.mp4'
# [09/12/23 06:54:02] INFO     Animation 13 : Partial movie file written in                  ]8;id=590403;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=886422;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_634088727_1570504939.mp4'
# [09/12/23 06:54:03] INFO     Animation 14 : Partial movie file written in                  ]8;id=936820;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=789739;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_3515528853.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=993198;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=820815;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=98439;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=196517;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=969799;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=843341;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 6 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=12075;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=545042;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@06-54-03.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Test
# class Test(Scene):
#             def construct(self):
#                 test=MathTex(f"${Theta}")
#                 self.play(Write(test))
#                 self.wait()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 49 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Test', 'class Test(Scene):\n            def construct(self):\n                test=MathTex(f"${Theta}")\n                self.play(Write(test))\n                self.wait()\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:3, in construct(self)
#
# NameError: name 'Theta' is not defined

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier=ArcBetweenPoints(start=[0.5,0,0],end=[0.50,np.tan(angular)*0.5,0],angle=angular,radius=0.3)
#         theta_signifier=ArcBetweenPoints(start=[-0.5,0,0],end=[-0.50,np.tan(angular)*0.5,0],angle=angular, radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan),run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,alpha_signifier,theta_signifier)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 07:57:03] INFO     Animation 0 : Using cached data (hash :                           ]8;id=85606;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=422894;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
# [09/12/23 07:57:04] INFO     Animation 1 : Using cached data (hash :                           ]8;id=952248;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=773947;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=408655;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=886738;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=120983;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=401927;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=172813;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=369912;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/12/23 07:57:06] INFO     Animation 5 : Partial movie file written in                   ]8;id=970645;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=972866;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_811432457_1659206401.mp4'
#                     INFO     Animation 6 : Partial movie file written in                   ]8;id=553368;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=713925;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_1488519456.mp4
#                              '
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=389800;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=767026;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
# [09/12/23 07:57:07] INFO     Animation 8 : Using cached data (hash :                           ]8;id=705899;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=544462;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=579296;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=233013;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3936732207)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=679648;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=687349;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2051165797_3080706144)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=969876;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=535954;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3664981868_2100960209)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=333274;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=417463;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2086748044)
# [09/12/23 07:57:08] INFO     Animation 13 : Partial movie file written in                  ]8;id=862767;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=3455;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2352592166_352835781.mp4'
# [09/12/23 07:57:09] INFO     Animation 14 : Partial movie file written in                  ]8;id=780611;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=715191;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_1986405069.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=476537;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=402144;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=355527;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=803530;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=843853;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=677562;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 4 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=917896;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=1885;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@07-57-09.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier=ArcBetweenPoints(start=[0.5,0,0],end=[0.50,np.tan(angular)*0.5,0],angle=angular,radius=0.3)
#         theta_signifier=ArcBetweenPoints(start=[-0.5,0,0],end=[-0.50,np.tan(angular)*0.5,0],angle=angular, radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan),run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,alpha_signifier,theta_signifier)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#         # duplicate both the triangles, enlarge it and use theta
#         #brace needed
#
#         class Test(Scene):
#             def construct(self):
#                 test=Tex(f"Theta")
#                 self.write(test)
#                 self.wait()
# Out:
# UsageError: Cell magic `%%manim` not found.

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm Intro
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier,radius_text),2*PI,about_point=[0,0,0],run_time=2),Create(circ),run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular=PI/180 *25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular),3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular),0, 0]),
#         ]
#         vertices_sin_a=Line(start=[0,0,0], end=[3*np.cos(angular),3*np.sin(angular),0])
#         vertices_sin_b=Line(start=[3*np.cos(angular),0,0] ,end=[3*np.sin(angular),0,0])
#         vertices_sin_c=Line(start=[3*np.sin(angular),0,0], end=[0,0,0])
#
#         lines=VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#
#         radius_tan=3/np.cos(angular)
#         vertices_tan =[
#             np.array([0,0,0]),
#             np.array([-radius_tan*np.cos(angular),radius_tan*np.sin(angular),0]),
#             np.array([-3,0,0]),
#
#         ]
#
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier=ArcBetweenPoints(start=[0.5,0,0],end=[0.50,np.tan(angular)*0.5,0],angle=angular,radius=0.3)
#         theta_signifier=ArcBetweenPoints(start=[-0.5,0,0],end=[-0.50,np.tan(angular)*0.5,0],angle=angular, radius=0.3)
#         self.play(Create(triangle_sin),run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan),run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         self.wait()
#         together=VGroup(triangle_sin,circ,diameter_signifier,triangle_tan,alpha_signifier,theta_signifier)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#         # duplicate both the triangles, enlarge it and use theta
#         #brace needed
#
#         class Test(Scene):
#             def construct(self):
#                 test=Tex(f"Theta")
#                 self.write(test)
#                 self.wait()
# Out:
# [09/12/23 11:45:04] INFO     Animation 0 : Using cached data (hash :                           ]8;id=437433;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=945376;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1823073981_223132457)
# [09/12/23 11:45:05] INFO     Animation 1 : Using cached data (hash :                           ]8;id=671945;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=176610;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3623726045_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=432067;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=61787;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_549977174)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=436983;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=963017;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_3049270095)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=542528;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=409322;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3721154580_2109712235)
# [09/12/23 11:45:08] INFO     Animation 5 : Partial movie file written in                   ]8;id=572346;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=68935;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1667920919_3339812486.mp4
#                              '
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=801239;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=320267;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_3805602405)
# [09/12/23 11:45:11] INFO     Animation 7 : Partial movie file written in                   ]8;id=974436;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=558497;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2029965998_2669184727.mp4
#                              '
# [09/12/23 11:45:13] INFO     Animation 8 : Partial movie file written in                   ]8;id=251374;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=733941;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_205815995_1049018057.mp4'
# [09/12/23 11:45:14] INFO     Animation 9 : Partial movie file written in                   ]8;id=539157;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=301871;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_4084458687_1485746165.mp4
#                              '
# [09/12/23 11:45:16] INFO     Animation 10 : Partial movie file written in                  ]8;id=4392;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=46667;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1731054582_1332548796.mp4
#                              '
# [09/12/23 11:45:17] INFO     Animation 11 : Partial movie file written in                  ]8;id=637225;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=495868;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_241297516_1548024928.mp4'
# [09/12/23 11:45:19] INFO     Animation 12 : Partial movie file written in                  ]8;id=366577;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=350455;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_3723565348.mp4
#                              '
# [09/12/23 11:45:20] INFO     Animation 13 : Partial movie file written in                  ]8;id=605897;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=589954;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2352592166_2418458332.mp4
#                              '
# [09/12/23 11:45:21] INFO     Animation 14 : Partial movie file written in                  ]8;id=748400;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=862706;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_1359202763.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=416956;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=970381;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=51962;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=577219;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=694153;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=710274;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 9 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
# [09/12/23 11:45:22] INFO     Rendered Intro                                                            ]8;id=982735;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=267648;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@11-45-22.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[-0.5, 0, 0], end=[-0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 11:53:31] INFO     Animation 0 : Using cached data (hash :                           ]8;id=215917;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=787444;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=878938;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=201318;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=598573;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=687407;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=407820;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=854089;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
# [09/12/23 11:53:32] INFO     Animation 4 : Using cached data (hash :                           ]8;id=25563;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=454601;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=988642;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=991049;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=281845;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=414164;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=401255;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=483458;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=659094;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=102376;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=200666;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=977206;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3936732207)
# [09/12/23 11:53:33] INFO     Animation 10 : Partial movie file written in                  ]8;id=609441;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=267774;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2714977301_3080706144.mp4
#                              '
# [09/12/23 11:53:34] INFO     Animation 11 : Partial movie file written in                  ]8;id=853527;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=283030;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_241297516_1405269611.mp4'
# [09/12/23 11:53:35] INFO     Animation 12 : Partial movie file written in                  ]8;id=638957;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=692875;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_1660017561.mp4
#                              '
# [09/12/23 11:53:36] INFO     Animation 13 : Partial movie file written in                  ]8;id=189322;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=646089;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3072606822_352835781.mp4'
#                     INFO     Animation 14 : Partial movie file written in                  ]8;id=724487;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=665665;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_1910045381.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=780137;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=172142;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=485733;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=604885;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=357516;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=520274;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 5 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=177945;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=510111;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@11-53-36.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[-0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         theta=MathTex(r"\theta")
#         self.add(theta.next_to(theta_signifier,RIGHT))
#         self.add(theta.next_to(alpha_signifier,RIGHT)
#         )
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 11:57:26] INFO     Animation 0 : Using cached data (hash :                           ]8;id=639042;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=798343;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=471976;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=292372;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=141051;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=881148;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=392499;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=626418;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=171884;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=385334;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=907597;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=971542;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
# [09/12/23 11:57:27] INFO     Animation 6 : Using cached data (hash :                           ]8;id=555197;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=90621;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=643951;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=17991;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 55 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', '\n\nclass Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n\n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,\n                  about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)\n\n        # chaine kura ho\n        self.wait()\n\n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular = PI/180 * 25\n        vertices_sin = [\n            np.array([0, 0, 0]),\n            np.array([3*np.cos(angular), 3*np.sin(angular), 0]),\n            np.array([3*np.cos(angular), 0, 0]),\n        ]\n        vertices_sin_a = Line(start=[0, 0, 0], end=[\n                              3*np.cos(angular), 3*np.sin(angular), 0])\n        vertices_sin_b = Line(\n            start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])\n        vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])\n\n        lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)\n\n        radius_tan = 3/np.cos(angular)\n        vertices_tan = [\n            np.array([0, 0, 0]),\n            np.array([radius_tan*np.cos(angular),\n                     radius_tan*np.sin(angular), 0]),\n            np.array([3, 0, 0]),\n\n        ]\n\n        self.play(FadeOut(radius_text))\n        triangle_sin = Polygon(*vertices_sin, color=BLUE)\n        triangle_tan = Polygon(*vertices_tan, color=GREEN)\n\n        alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[\n                                           0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)\n        theta_signifier = ArcBetweenPoints(\n            start=[-0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)\n        self.play(Create(triangle_sin), run_time=3)\n        self.play(Create(alpha_signifier))\n        self.play(Create(triangle_tan), run_time=3)\n        self.play(Create(theta_signifier))\n        # self.add(lines)\n        theta=MathTex(r"\\theta")\n        self.add(theta.next_to(theta_signifier,RIGHT))\n        self.add(theta.next_to(alpha_signifier,RIGHT)\n        )\n\n        self.wait()\n        together = VGroup(triangle_sin, circ, diameter_signifier,\n                          triangle_tan, alpha_signifier, theta_signifier,theta)\n        self.play(together.animate.move_to(3*LEFT))\n        # self.play((lines.animate.move_to(5*RIGHT+2*UP)))\n        self.wait()\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:56, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\arc.py:427, in ArcBetweenPoints.__init__(self, start, end, angle, radius, **kwargs)
#     425 halfdist = np.linalg.norm(np.array(start) - np.array(end)) / 2
#     426 if radius < halfdist:
# --> 427     raise ValueError(
#     428         """ArcBetweenPoints called with a radius that is
#     429                 smaller than half the distance between the points.""",
#     430     )
#     431 arc_height = radius - math.sqrt(radius**2 - halfdist**2)
#     432 angle = math.acos((radius - arc_height) / radius) * sign
#
# ValueError: ArcBetweenPoints called with a radius that is
#                             smaller than half the distance between the points.

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, 0, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[-0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         theta=MathTex(r"\theta")
#         self.add(theta.next_to(theta_signifier,RIGHT))
#         self.add(theta.next_to(alpha_signifier,RIGHT)
#         )
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#         # duplicate both the triangles, enlarge it and use theta
#         # brace needed
#
#         class Test(Scene):
#             def construct(self):
#                 test = MathTex("\Theta")
#                 self.write(test)
#                 self.wait()
# Out:
# UsageError: Cell magic `%%manim` not found.

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, 0, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[-0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         theta=MathTex(r"\theta")
#         self.add(theta.next_to(theta_signifier,RIGHT))
#         self.add(theta.next_to(alpha_signifier,RIGHT)
#         )
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#         # duplicate both the triangles, enlarge it and use theta
#         # brace needed
#
#         class Test(Scene):
#             def construct(self):
#                 test = MathTex("\Theta")
#                 self.write(test)
#                 self.wait()
# Out:
# [09/12/23 11:59:46] INFO     Animation 0 : Using cached data (hash :                           ]8;id=890418;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=158789;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1823073981_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=539574;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=505284;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3623726045_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=981317;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=995365;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_549977174)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=807188;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=821270;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_3049270095)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=377565;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=800138;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3721154580_2109712235)
# [09/12/23 11:59:47] INFO     Animation 5 : Using cached data (hash :                           ]8;id=237721;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=135671;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_4190124686_3339812486)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=807833;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=874389;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_3805602405)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=422506;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=270655;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2029965998_2669184727)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Adish\manim-adish\notebook.ipynb Cell 58 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adish/manim-adish/notebook.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('manim', '-qm Intro', '\n\nclass Intro(Scene):\n    def construct(self):\n        circ = Circle(radius=3, color=WHITE)\n        sqr = Square()\n        numberplane = NumberPlane()\n        equation = MathTex("x^2+y^2=r^2")\n        diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])\n\n        self.play(\n            Write(equation)\n        )\n        self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)\n        self.wait()\n        self.play(Create(diameter_signifier))\n        radius_text = MathTex("r")\n        self.play(Write(radius_text.move_to([1.5, -0.2, 0])))\n        self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,\n                  about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)\n\n        # chaine kura ho\n        self.wait()\n\n# class Triangle_rendering(Scene):\n#     def construct(self):\n        angular = PI/180 * 25\n        vertices_sin = [\n            np.array([0, 0, 0]),\n            np.array([3*np.cos(angular), 3*np.sin(angular), 0]),\n            np.array([3*np.cos(angular), 0, 0]),\n        ]\n        vertices_sin_a = Line(start=[0, 0, 0], end=[\n                              3*np.cos(angular), 3*np.sin(angular), 0])\n        vertices_sin_b = Line(\n            start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])\n        vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])\n\n        lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)\n\n        radius_tan = 3/np.cos(angular)\n        vertices_tan = [\n            np.array([0, 0, 0]),\n            np.array([radius_tan*np.cos(angular),\n                     radius_tan*np.sin(angular), 0]),\n            np.array([3, 0, 0]),\n\n        ]\n\n        self.play(FadeOut(radius_text))\n        triangle_sin = Polygon(*vertices_sin, color=BLUE)\n        triangle_tan = Polygon(*vertices_tan, color=GREEN)\n\n        alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[\n                                           0.5, 0, 0], angle=angular, radius=0.3)\n        theta_signifier = ArcBetweenPoints(\n            start=[-0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)\n        self.play(Create(triangle_sin), run_time=3)\n        self.play(Create(alpha_signifier))\n        self.play(Create(triangle_tan), run_time=3)\n        self.play(Create(theta_signifier))\n        # self.add(lines)\n        theta=MathTex(r"\\theta")\n        self.add(theta.next_to(theta_signifier,RIGHT))\n        self.add(theta.next_to(alpha_signifier,RIGHT)\n        )\n\n        self.wait()\n        together = VGroup(triangle_sin, circ, diameter_signifier,\n                          triangle_tan, alpha_signifier, theta_signifier,theta)\n        self.play(together.animate.move_to(3*LEFT))\n        # self.play((lines.animate.move_to(5*RIGHT+2*UP)))\n        self.wait()\n\n        # duplicate both the triangles, enlarge it and use theta\n        # brace needed\n\n        class Test(Scene):\n            def construct(self):\n                test = MathTex("\\Theta")\n                self.write(test)\n                self.wait()\n')
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:56, in construct(self)
#
# File c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\mobject\geometry\arc.py:427, in ArcBetweenPoints.__init__(self, start, end, angle, radius, **kwargs)
#     425 halfdist = np.linalg.norm(np.array(start) - np.array(end)) / 2
#     426 if radius < halfdist:
# --> 427     raise ValueError(
#     428         """ArcBetweenPoints called with a radius that is
#     429                 smaller than half the distance between the points.""",
#     430     )
#     431 arc_height = radius - math.sqrt(radius**2 - halfdist**2)
#     432 angle = math.acos((radius - arc_height) / radius) * sign
#
# ValueError: ArcBetweenPoints called with a radius that is
#                             smaller than half the distance between the points.

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#         self.play(Create(alpha_signifier))
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         # self.add(lines)
#         theta=MathTex(r"\theta")
#         self.add(theta.next_to(theta_signifier,RIGHT))
#         self.add(theta.next_to(alpha_signifier,RIGHT)
#         )
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 12:02:22] INFO     Animation 0 : Using cached data (hash :                           ]8;id=938100;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=245474;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=35367;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=573067;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=176735;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=323709;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
# [09/12/23 12:02:23] INFO     Animation 3 : Using cached data (hash :                           ]8;id=550106;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=301404;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=369938;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=606618;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=894990;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=263549;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=815246;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=889312;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=516529;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=907398;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=619423;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=896599;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
# [09/12/23 12:02:24] INFO     Animation 9 : Partial movie file written in                   ]8;id=912386;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=257206;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3566532986_3936732207.mp4
#                              '
# [09/12/23 12:02:26] INFO     Animation 10 : Partial movie file written in                  ]8;id=270013;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=519072;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2714977301_3088203226.mp4
#                              '
# [09/12/23 12:02:27] INFO     Animation 11 : Partial movie file written in                  ]8;id=918166;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=400321;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_4084458687_3088555543.mp4
#                              '
#                     INFO     Animation 12 : Partial movie file written in                  ]8;id=241015;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=618681;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_1925371045.mp4'
# [09/12/23 12:02:28] INFO     Animation 13 : Partial movie file written in                  ]8;id=188417;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=321881;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3167050474_515125311.mp4'
# [09/12/23 12:02:29] INFO     Animation 14 : Partial movie file written in                  ]8;id=593411;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=915816;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_41213939.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=231102;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=386595;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=79819;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=321368;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=205388;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=904452;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 6 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=410293;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=667125;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@12-02-29.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,))
#         self.add(theta.next_to(alpha_signifier,RIGHT)
#         )
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 12:06:40] INFO     Animation 0 : Using cached data (hash :                           ]8;id=321807;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=739184;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=493626;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=736518;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/12/23 12:06:41] INFO     Animation 2 : Using cached data (hash :                           ]8;id=560591;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=798235;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=586567;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=929442;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=744859;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=920909;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=467550;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=34569;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_811432457_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=514717;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=480336;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=320442;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=416888;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=669226;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=442882;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
# [09/12/23 12:06:42] INFO     Animation 9 : Using cached data (hash :                           ]8;id=754257;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=594859;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=142341;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=882157;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=398358;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=136126;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Partial movie file written in                  ]8;id=298329;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13942;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_32607171.mp4'
# [09/12/23 12:06:43] INFO     Animation 13 : Partial movie file written in                  ]8;id=598478;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=269555;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3531897758_515125311.mp4'
# [09/12/23 12:06:44] INFO     Animation 14 : Partial movie file written in                  ]8;id=121728;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=600174;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2645012705.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=485786;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=65198;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=92559;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=929901;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=713354;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=347223;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=781291;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=197167;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@12-06-44.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT))
#         self.add(theta.next_to(alpha_signifier,RIGHT)
#         )
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 12:09:01] INFO     Animation 0 : Using cached data (hash :                           ]8;id=143180;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=553339;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=524314;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=782131;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=737860;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=156495;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=192857;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=681325;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=951115;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=22439;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/12/23 12:09:02] INFO     Animation 5 : Partial movie file written in                   ]8;id=949341;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=402724;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_365313117_1659206401.mp4'
# [09/12/23 12:09:03] INFO     Animation 6 : Using cached data (hash :                           ]8;id=111998;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=342890;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3315967912_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=953049;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=32784;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=53426;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=349958;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=714136;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=161870;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=898979;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=450157;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=782350;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=501177;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=783176;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=435689;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_32607171)
# [09/12/23 12:09:05] INFO     Animation 13 : Partial movie file written in                  ]8;id=125734;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=742141;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_705401776_515125311.mp4'
#                     INFO     Animation 14 : Partial movie file written in                  ]8;id=939659;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=403919;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_2645012705.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=986006;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=766050;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=325183;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=179286;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=394499;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=830658;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=570570;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=987256;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@12-09-05.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 12:47:46] INFO     Animation 0 : Using cached data (hash :                           ]8;id=754273;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=291612;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=960964;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=885553;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=634753;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=344541;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=39040;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=368170;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=992653;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=212053;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/12/23 12:47:47] INFO     Animation 5 : Using cached data (hash :                           ]8;id=804316;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=341074;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=575549;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=495046;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3315967912_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=673139;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=601334;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=305026;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=483046;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=502006;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=326862;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=126186;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=289208;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=952069;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=897433;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
# [09/12/23 12:47:48] INFO     Animation 12 : Partial movie file written in                  ]8;id=600807;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=457346;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_329969645_3122074744.mp4'
# [09/12/23 12:47:49] INFO     Animation 13 : Partial movie file written in                  ]8;id=613553;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=784378;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2933728251_515125311.mp4'
#                     INFO     Animation 14 : Partial movie file written in                  ]8;id=833448;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=608548;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_3732106400.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=150355;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=191895;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/12/23 12:47:50] INFO                                                                   ]8;id=637572;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=206139;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=402237;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=271674;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=974481;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=470739;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@12-47-50.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
# Out:
# [09/12/23 12:51:05] INFO     Animation 0 : Using cached data (hash :                           ]8;id=140489;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=234958;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=44408;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=465566;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=774083;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=467255;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=86463;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=475808;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=940004;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=926143;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=161945;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=183390;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
# [09/12/23 12:51:06] INFO     Animation 6 : Using cached data (hash :                           ]8;id=402013;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=179546;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=719656;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=712067;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=64964;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=936618;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              207390714_1163585900_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=213251;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=910759;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=369350;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=882001;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=665074;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=546327;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=603005;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=691231;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_591746866)
# [09/12/23 12:51:07] INFO     Animation 13 : Partial movie file written in                  ]8;id=615019;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=624114;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3217385909_515125311.mp4'
# [09/12/23 12:51:08] INFO     Animation 14 : Partial movie file written in                  ]8;id=498006;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=118378;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_2774490366.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=415249;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=166970;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=430889;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=537350;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=666903;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=598611;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=658104;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=553366;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 15 animations
# <video src="media\jupyter\Intro@2023-09-12@12-51-08.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
# Out:
# [09/12/23 18:04:54] INFO     Animation 0 : Using cached data (hash :                           ]8;id=392983;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=727755;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=232284;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=303429;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=389992;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=736632;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=262456;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=129858;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=687453;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=559682;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
# [09/12/23 18:04:55] INFO     Animation 5 : Using cached data (hash :                           ]8;id=788900;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=409660;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              207390714_3793641409_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=379501;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=125431;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=213399;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=479898;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=332215;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=236406;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=594489;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=761412;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=209594;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=169051;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
# [09/12/23 18:04:56] INFO     Animation 11 : Using cached data (hash :                          ]8;id=434545;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=200657;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=547267;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=533937;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_591746866)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=408418;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=521214;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3217385909_515125311)
#                     INFO     Animation 14 : Using cached data (hash :                          ]8;id=920533;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=790509;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2774490366)
# [09/12/23 18:04:57] INFO     Animation 15 : Partial movie file written in                  ]8;id=482848;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=359629;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1638740670_996551268.mp4'
# [09/12/23 18:04:58] INFO     Animation 16 : Partial movie file written in                  ]8;id=233309;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=439077;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_3714327449.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=437304;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=14646;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=93673;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=164764;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=337522;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=372788;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=900521;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=546071;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 17 animations
# <video src="media\jupyter\Intro@2023-09-12@18-04-58.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#         self.add(vertices_sin_c)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
# Out:
# [09/12/23 18:10:23] INFO     Animation 0 : Using cached data (hash :                           ]8;id=486346;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=632156;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=12799;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=804011;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=575069;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=485635;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=969319;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=375596;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=118430;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=963265;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=729230;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=227067;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=659593;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=848801;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=6906;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=502170;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
# [09/12/23 18:10:24] INFO     Animation 8 : Using cached data (hash :                           ]8;id=71411;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=720517;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=930685;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=264377;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=664004;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=454087;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=346079;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=6524;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=710480;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=380976;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_591746866)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=475904;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=343243;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3217385909_515125311)
# [09/12/23 18:10:25] INFO     Animation 14 : Using cached data (hash :                          ]8;id=869001;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=282247;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2774490366)
#                     INFO     Animation 15 : Partial movie file written in                  ]8;id=160937;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=103267;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_1498277410_1335845012.mp4
#                              '
# [09/12/23 18:10:26] INFO     Animation 16 : Partial movie file written in                  ]8;id=428627;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=718140;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_3148270493.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=367804;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=381862;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=275279;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=103596;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=427624;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=191572;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=613030;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=356740;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 17 animations
# <video src="media\jupyter\Intro@2023-09-12@18-10-26.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#         vertices_sin_a = Line(start=[0, 0, 0], end=[
#                               3*np.cos(angular), 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular), 0, 0], end=[3*np.sin(angular), 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular), 0, 0], end=[0, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#         vertices_sin_copy=Line(start=[-3,0,0],end=[np.cos(angular)*3-3,0,0],color=BLUE)
#         self.add(vertices_sin_copy)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
#         sin_=VGroup(triangle_sin,theta_signifier,theta)
#         self.play(FadeOut(vertices_sin_copy))
#
#         self.play(sin_.animate.move_to(5*RIGHT+1.5*UP))
#         tex_=MathTex(r"sin(\theta)=P/H")
#         self.play(Write(tex_.next_to(triangle_sin,DOWN)))
#         important=Brace(vertices_sin_a,sharpness=2)
#         self.play(Create(important))
#
#         self.wait()
# Out:
# [09/12/23 18:53:51] INFO     Animation 0 : Using cached data (hash :                           ]8;id=989533;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=119487;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=756425;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=382256;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=974585;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=878579;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
# [09/12/23 18:53:52] INFO     Animation 3 : Using cached data (hash :                           ]8;id=197196;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=988814;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=105567;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=818610;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=444385;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=832061;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=363764;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=627755;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=369618;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=86238;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=13911;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=46826;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
# [09/12/23 18:53:53] INFO     Animation 9 : Using cached data (hash :                           ]8;id=647312;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=780525;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=277760;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=842855;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=537580;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=424379;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=170509;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=114396;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_591746866)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=277035;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=178336;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3217385909_515125311)
# [09/12/23 18:53:54] INFO     Animation 14 : Using cached data (hash :                          ]8;id=551257;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=844209;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2774490366)
#                     INFO     Animation 15 : Using cached data (hash :                          ]8;id=646000;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=93814;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_336080905_2541963097)
#                     INFO     Animation 16 : Using cached data (hash :                          ]8;id=405401;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=931666;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1886039174)
#                     INFO     Animation 17 : Using cached data (hash :                          ]8;id=209937;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=588540;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_78855461_2942640139)
# [09/12/23 18:53:55] INFO     Animation 18 : Using cached data (hash :                          ]8;id=247419;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=999466;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1597114801_3293302928)
#                     INFO     Animation 19 : Using cached data (hash :                          ]8;id=534284;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=628347;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1843145597_697279629)
# [09/12/23 18:53:56] INFO     Animation 20 : Partial movie file written in                  ]8;id=965133;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=593184;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_2279558459_2314636024.mp4
#                              '
# [09/12/23 18:53:57] INFO     Animation 21 : Partial movie file written in                  ]8;id=441997;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=885505;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\207390714_3315967912_506577793.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=271953;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=626522;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/12/23 18:53:58] INFO                                                                   ]8;id=828427;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=481732;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=91240;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=317609;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=523341;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=233663;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 22 animations
# <video src="media\jupyter\Intro@2023-09-12@18-53-58.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#         vertices_sin_copy=Line(start=[-3,0,0],end=[np.cos(angular)*3-3,0,0],color=BLUE)
#         self.add(vertices_sin_copy)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
#
#         sin_=VGroup(triangle_sin,theta_signifier,theta)
#         self.play(FadeOut(vertices_sin_copy))
#         self.play(sin_.animate.move_to(5*RIGHT+1.5*UP))
#         tex_=MathTex(r"sin(\theta)=P/H")
#         self.play(Write(tex_.next_to(triangle_sin,DOWN)))
#
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)-3, 0, 0], end=[3*np.sin(angular)-3, 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular)-3, 0, 0], end=[-3, 0, 0])
#
#         lines = VGroup(vertices_sin_a, vertices_sin_b, vertices_sin_c)
#
#         important=Brace(vertices_sin_a,sharpness=2,direction=(vertices_sin_a.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important))
#         important_text=important.get_tex("r")
#         self.play(Write(important_text))
#         self.wait(2)
# Out:
# [09/12/23 19:02:24] INFO     Animation 0 : Using cached data (hash :                           ]8;id=335627;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=994411;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=507348;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=674889;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
# [09/12/23 19:02:25] INFO     Animation 2 : Using cached data (hash :                           ]8;id=506386;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=459798;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=468873;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=153178;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=580425;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=659661;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=923614;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=499524;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=891435;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=839493;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
# [09/12/23 19:02:26] INFO     Animation 7 : Using cached data (hash :                           ]8;id=894201;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=260460;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=717594;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=232464;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=87680;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=858452;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=419406;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=209247;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=765880;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=741303;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=802230;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=563814;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_591746866)
# [09/12/23 19:02:27] INFO     Animation 13 : Using cached data (hash :                          ]8;id=126216;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=7756;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3217385909_515125311)
#                     INFO     Animation 14 : Using cached data (hash :                          ]8;id=109986;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=53782;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2774490366)
#                     INFO     Animation 15 : Using cached data (hash :                          ]8;id=720030;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=297471;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1498277410_2541963097)
#                     INFO     Animation 16 : Using cached data (hash :                          ]8;id=704104;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=291589;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1886039174)
#                     INFO     Animation 17 : Using cached data (hash :                          ]8;id=726142;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=574050;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_78855461_2942640139)
# [09/12/23 19:02:28] INFO     Animation 18 : Using cached data (hash :                          ]8;id=662416;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=484087;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1597114801_3293302928)
#                     INFO     Animation 19 : Using cached data (hash :                          ]8;id=568695;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=868791;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1843145597_697279629)
#                     INFO     Animation 20 : Using cached data (hash :                          ]8;id=184505;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=213620;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3939017015_2314636024)
# [09/12/23 19:02:29] INFO     Animation 21 : Partial movie file written in                  ]8;id=777668;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=848488;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_725517781_503686337.mp4'
# [09/12/23 19:02:30] INFO     Animation 22 : Partial movie file written in                  ]8;id=350793;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=944225;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_125286499_1801168443.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=297806;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=697592;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/12/23 19:02:31] INFO                                                                   ]8;id=572949;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=736581;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=227051;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=471523;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=69154;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=477381;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 23 animations
# <video src="media\jupyter\Intro@2023-09-12@19-02-31.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#         vertices_sin_copy=Line(start=[-3,0,0],end=[np.cos(angular)*3-3,0,0],color=BLUE)
#         self.add(vertices_sin_copy)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)-3, 0, 0], end=[3*np.sin(angular)-3, 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular)-3, 0, 0], end=[-3, 0, 0])
#
#         self.play(FadeOut(vertices_sin_copy))
#         important=Brace(vertices_sin_a,sharpness=2,direction=(vertices_sin_a.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important))
#         important_text=important.get_tex("r")
#         self.play(Write(important_text))
#         sin_=VGroup(triangle_sin,theta_signifier,theta,important,important_text)
#         self.play(sin_.animate.move_to(5*RIGHT+1.5*UP))
#         tex_1=MathTex(r"sin(\theta)=P_1/H")
#         tex_2=MathTex(r"Hsin(\theta)=P_1")
#         tex_3=MathTex(r"P_1=rsin(\theta)")
#         self.play(Write(
#         tex_1.next_to(triangle_sin,DOWN),))
#         self.play(Write(tex_2.next_to(tex_1,DOWN)))
#         self.play(Write(tex_3.next_to(tex_2,DOWN)))
#         self.wait()
#
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)+7-3,0.5, 0], end=[3*np.cos(angular)+7-3, 3*np.sin(angular)+0.5, 0])
#         vertices_sin_c = Line(start=[-3*np.sin(angular)+3, 0, 0], end=[-3, 0, 0])
#
#         self.play(
#             FadeOut(tex_1),
#             FadeOut(tex_2)),
#         self.play(tex_3.animate.next_to(triangle_sin,DOWN))
#         self.wait()
#         self.play(sin_.animate.move_to(2*RIGHT+1.5*UP))
#
#         important1=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(-PI/2).get_unit_vector()))
#         self.play(Create(important1.next_to(triangle_sin,RIGHT)))
#         self.play(Create(tex_3.next_to(important1,RIGHT)))
#         self.wait()
#
#         reverse=VGroup(triangle_sin,theta,theta_signifier,important,important_text,important1,tex_3)
#         reverse_coordinates=[-PI,0,0]
#         self.play(reverse.animate.align_to(reverse_coordinates,LEFT))
#         self.play(reverse.animate.align_to([-3,0,0],DOWN))
#         self.wait()
# Out:
# [09/12/23 22:25:24] INFO     Animation 0 : Using cached data (hash :                           ]8;id=673749;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=95122;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_1472493994_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=179856;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=376338;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1887582972_2047478226)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=51618;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=530443;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1839938303)
# [09/12/23 22:25:25] INFO     Animation 3 : Using cached data (hash :                           ]8;id=932813;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=2407;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1248676425_1862034798)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=878378;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=337216;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1565194538_1328761151)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=861989;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=402290;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2119785575_1659206401)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=745652;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=441272;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1488519456)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=557054;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=588689;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_784930149_3546483927)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=397410;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=350448;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_205815995_2879665698)
# [09/12/23 22:25:26] INFO     Animation 9 : Using cached data (hash :                           ]8;id=288340;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=182718;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2714977301_3454062966)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=167228;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=344313;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2033897173_3259475065)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=874741;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=900536;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3566532986_1648907167)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=898595;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=83894;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_591746866)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=578635;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=295379;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3217385909_515125311)
#                     INFO     Animation 14 : Using cached data (hash :                          ]8;id=178336;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=983429;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_2774490366)
# [09/12/23 22:25:27] INFO     Animation 15 : Using cached data (hash :                          ]8;id=157287;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=219908;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1498277410_2541963097)
#                     INFO     Animation 16 : Using cached data (hash :                          ]8;id=336786;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=427917;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1886039174)
#                     INFO     Animation 17 : Using cached data (hash :                          ]8;id=479404;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=923331;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_78855461_2942640139)
#                     INFO     Animation 18 : Using cached data (hash :                          ]8;id=444751;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=334016;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3939017015_127928502)
#                     INFO     Animation 19 : Using cached data (hash :                          ]8;id=94069;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=515574;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_725517781_3636351932)
# [09/12/23 22:25:28] INFO     Animation 20 : Using cached data (hash :                          ]8;id=469095;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=292422;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_742642887_3293302928)
#                     INFO     Animation 21 : Using cached data (hash :                          ]8;id=414509;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=221705;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2436891050_3186971118)
# [09/12/23 22:25:29] INFO     Animation 22 : Using cached data (hash :                          ]8;id=122788;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=960480;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2743604731_1201788783)
#                     INFO     Animation 23 : Using cached data (hash :                          ]8;id=409408;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=40822;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_419149345_1685557535)
#                     INFO     Animation 24 : Using cached data (hash :                          ]8;id=73;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=606374;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_4178478861)
# [09/12/23 22:25:30] INFO     Animation 25 : Using cached data (hash :                          ]8;id=43549;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=644388;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_2691535429_3302196633)
#                     INFO     Animation 26 : Using cached data (hash :                          ]8;id=138263;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=306837;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_3175116489_1789966671)
#                     INFO     Animation 27 : Using cached data (hash :                          ]8;id=978196;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=94277;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_1056566681)
# [09/12/23 22:25:31] INFO     Animation 28 : Using cached data (hash :                          ]8;id=728225;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=995795;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1529557105_896350790)
#                     INFO     Animation 29 : Using cached data (hash :                          ]8;id=350957;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=67784;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1965114637_3900050644)
#                     INFO     Animation 30 : Using cached data (hash :                          ]8;id=604547;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=690858;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_1235887258_156965154)
# [09/12/23 22:25:32] INFO     Animation 31 : Using cached data (hash :                          ]8;id=731380;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=343071;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              2789044632_329969645_821775335)
# [09/12/23 22:25:33] INFO     Animation 32 : Partial movie file written in                  ]8;id=342140;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=788273;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_271573335_3083562420.mp4'
# [09/12/23 22:25:34] INFO     Animation 33 : Partial movie file written in                  ]8;id=192256;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=132740;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_4170789527_3083562420.mp4
#                              '
# [09/12/23 22:25:35] INFO     Animation 34 : Partial movie file written in                  ]8;id=228022;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=275763;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\p
#                              artial_movie_files\Intro\2789044632_3315967912_4164301377.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=789811;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=730575;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
# [09/12/23 22:25:36] INFO                                                                   ]8;id=411019;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=194418;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\Adish\manim-adish\media\videos\manim-adish\720p30\I
#                              ntro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=697774;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=705661;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene_file_writer.py#708\708]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=56807;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=883966;file://c:\Users\Adish\manim-adish\mce\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 35 animations
# <video src="media\jupyter\Intro@2023-09-12@22-25-36.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#
#         vertices_sin_copy=Line(start=[-3,0,0],end=[np.cos(angular)*3-3,0,0],color=BLUE)
#         self.add(vertices_sin_copy)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)-3, 0, 0], end=[3*np.sin(angular)-3, 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular)-3, 0, 0], end=[-3, 0, 0])
#
#
#
#         self.play(FadeOut(vertices_sin_copy))
#
# #-----------------------------------------------------------------------
#         important=Brace(vertices_sin_a,sharpness=2,direction=(vertices_sin_a.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important))
#         important_text=important.get_tex("r")
#         self.play(Write(important_text))
#         sin_=VGroup(triangle_sin,theta_signifier,theta,important,important_text)
#         self.play(sin_.animate.move_to(5*RIGHT+1.5*UP))
#         tex_1=MathTex(r"sin(\theta)=P_1/H")
#         tex_2=MathTex(r"Hsin(\theta)=P_1")
#         tex_3=MathTex(r"P_1=rsin(\theta)")
#         tex_4=MathTex(r"P_1")
#         self.play(Write(
#         tex_1.next_to(triangle_sin,DOWN),))
#         self.play(Write(tex_2.next_to(tex_1,DOWN)))
#         self.play(Write(tex_3.next_to(tex_2,DOWN)))
#         self.wait()
#
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)+7-3,0.5, 0], end=[3*np.cos(angular)+7-3, 3*np.sin(angular)+0.5, 0])
#         vertices_sin_c = Line(start=[-3*np.sin(angular)+3, 0, 0], end=[-3, 0, 0])
#
#         self.play(
#             FadeOut(tex_1),
#             FadeOut(tex_2)),
#         self.play(tex_3.animate.next_to(triangle_sin,DOWN))
#         self.wait()
#         self.play(sin_.animate.move_to(2*RIGHT+1.5*UP))
#
#         important1=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(-PI/2).get_unit_vector()))
#         self.play(Create(important1.next_to(triangle_sin,RIGHT)))
#         self.play(Create(tex_3.next_to(important1,RIGHT)))
#         self.wait()
#
#         reverse=VGroup(triangle_sin,theta,theta_signifier,important,important_text,important1,tex_3)
#         reverse_coordinates=[-PI,0,0]
#         self.play(reverse.animate.align_to(reverse_coordinates,LEFT))
#         self.play(reverse.animate.align_to([-3,0,0],DOWN))
#         self.wait()
# # np.array([0, 0, 0]),
# #             np.array([radius_tan*np.cos(angular),
# #                      radius_tan*np.sin(angular), 0]),
# #             np.array([3, 0, 0]),
#
# #             vertices_tan_a=Line(start=[-3,0,0],end=[radius_tan*np.cos(angular)-3,]
#
#
#         self.play(FadeOut(important,important_text))
#
#         radius_tan_ez=Line(start=[-3,0,0],end=[-6,0,0])
#         important_tan=Brace(radius_tan_ez,sharpness=1,direction=(radius_tan_ez.copy().rotate(-PI/2).get_unit_vector()))
#         important_tan_text=important_tan.get_tex("r")
#         self.play(Create(important_tan))
#         self.play(Write(important_tan_text))
#         self.wait()
#
#         self.play(FadeOut(tex_3),
#         tex_4.animate.next_to(important1,RIGHT,buff=0.3)
#         )
#
#         tan_group_=VGroup(triangle_tan,alpha_signifier,theta_,important_tan,important_tan_text)
#         self.play(tan_group_.animate.move_to(5*RIGHT+1.2*UP))
#
#         tex_1_=MathTex(r"tan(\theta)=P_2/B")
#         tex_2_=MathTex(r"Btan(\theta)=P_2")
#         tex_3_=MathTex(r"P_2=rtan(\theta)",font_size=25)
#         tex_4_=MathTex(r"P_2",font_size=40)
#         self.play(Write(
#         tex_1_.next_to(triangle_tan,DOWN),))
#         self.play(Write(tex_2_.next_to(tex_1_,DOWN)))
#         self.play(Write(tex_3_.next_to(tex_2_,DOWN)))
#         important_tan_=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important_tan_.next_to(triangle_tan,LEFT)))
#         self.play(
#             FadeOut(tex_1_),
#             FadeOut(tex_2_),
#             tex_3_.animate.next_to(triangle_tan,DOWN),
#             FadeOut(important_tan),
#             FadeOut(important_tan_text)
#         )
#         self.play(tex_3_.animate.next_to(important_tan_,LEFT))
#         reverse_=VGroup(triangle_tan,theta_,alpha_signifier,important_tan_,tex_4_)
#         self.play(FadeOut(tex_3_),
#         tex_4_.animate.next_to(important_tan_,LEFT,buff=0.2)
#         )
#         reverse_coordinates_=[-3,0,0]
#         self.play(reverse_.animate.align_to(reverse_coordinates_,RIGHT))
#         self.play(reverse_.animate.align_to([-6,0,0],UP))
#         self.wait()
#
#         self.wait()
# Out:
# <video src="media\jupyter\Intro@2023-09-12@23-38-35.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm -v WARNING Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#
#         vertices_sin_copy=Line(start=[-3,0,0],end=[np.cos(angular)*3-3,0,0],color=BLUE)
#         self.add(vertices_sin_copy)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)-3, 0, 0], end=[3*np.sin(angular)-3, 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular)-3, 0, 0], end=[-3, 0, 0])
#
#
#
#         self.play(FadeOut(vertices_sin_copy))
#
# #-----------------------------------------------------------------------
#         important=Brace(vertices_sin_a,sharpness=2,direction=(vertices_sin_a.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important))
#         important_text=important.get_tex("r")
#         self.play(Write(important_text))
#         sin_=VGroup(triangle_sin,theta_signifier,theta,important,important_text)
#         self.play(sin_.animate.move_to(5*RIGHT+1.5*UP))
#         tex_1=MathTex(r"sin(\theta)=P_1/H")
#         tex_2=MathTex(r"Hsin(\theta)=P_1")
#         tex_3=MathTex(r"P_1=rsin(\theta)")
#         tex_4=MathTex(r"P_1")
#         self.play(Write(
#         tex_1.next_to(triangle_sin,DOWN),))
#         self.play(Write(tex_2.next_to(tex_1,DOWN)))
#         self.play(Write(tex_3.next_to(tex_2,DOWN)))
#         self.wait()
#
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)+7-3,0.5, 0], end=[3*np.cos(angular)+7-3, 3*np.sin(angular)+0.5, 0])
#         vertices_sin_c = Line(start=[-3*np.sin(angular)+3, 0, 0], end=[-3, 0, 0])
#
#         self.play(
#             FadeOut(tex_1),
#             FadeOut(tex_2)),
#         self.play(tex_3.animate.next_to(triangle_sin,DOWN))
#         self.wait()
#         self.play(sin_.animate.move_to(2*RIGHT+1.5*UP))
#
#         important1=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(-PI/2).get_unit_vector()))
#         self.play(Create(important1.next_to(triangle_sin,RIGHT)))
#         self.play(Create(tex_3.next_to(important1,RIGHT)))
#         self.wait()
#
#         reverse=VGroup(triangle_sin,theta,theta_signifier,important,important_text,important1,tex_3)
#         reverse_coordinates=[-PI,0,0]
#         self.play(reverse.animate.align_to(reverse_coordinates,LEFT))
#         self.play(reverse.animate.align_to([-3,0,0],DOWN))
#         self.wait()
# # np.array([0, 0, 0]),
# #             np.array([radius_tan*np.cos(angular),
# #                      radius_tan*np.sin(angular), 0]),
# #             np.array([3, 0, 0]),
#
# #             vertices_tan_a=Line(start=[-3,0,0],end=[radius_tan*np.cos(angular)-3,]
#
#
#         self.play(FadeOut(important,important_text))
#
#         radius_tan_ez=Line(start=[-3,0,0],end=[-6,0,0])
#         important_tan=Brace(radius_tan_ez,sharpness=1,direction=(radius_tan_ez.copy().rotate(-PI/2).get_unit_vector()))
#         important_tan_text=important_tan.get_tex("r")
#         self.play(Create(important_tan))
#         self.play(Write(important_tan_text))
#         self.wait()
#
#         self.play(FadeOut(tex_3),
#         tex_4.animate.next_to(important1,RIGHT,buff=0.3)
#         )
#
#         tan_group_=VGroup(triangle_tan,alpha_signifier,theta_,important_tan,important_tan_text)
#         self.play(tan_group_.animate.move_to(5*RIGHT+1.2*UP))
#
#         tex_1_=MathTex(r"tan(\theta)=P_2/B")
#         tex_2_=MathTex(r"Btan(\theta)=P_2")
#         tex_3_=MathTex(r"P_2=rtan(\theta)",font_size=25)
#         tex_4_=MathTex(r"P_2",font_size=40)
#         self.play(Write(
#         tex_1_.next_to(triangle_tan,DOWN),))
#         self.play(Write(tex_2_.next_to(tex_1_,DOWN)))
#         self.play(Write(tex_3_.next_to(tex_2_,DOWN)))
#         important_tan_=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important_tan_.next_to(triangle_tan,LEFT)))
#         self.play(
#             FadeOut(tex_1_),
#             FadeOut(tex_2_),
#             tex_3_.animate.next_to(triangle_tan,DOWN),
#             FadeOut(important_tan),
#             FadeOut(important_tan_text)
#         )
#         self.play(tex_3_.animate.next_to(important_tan_,LEFT))
#         reverse_=VGroup(triangle_tan,theta_,alpha_signifier,important_tan_,tex_4_)
#         self.play(FadeOut(tex_3_),
#         tex_4_.animate.next_to(important_tan_,LEFT,buff=0.2)
#         )
#         reverse_coordinates_=[-3,0,0]
#         self.play(reverse_.animate.align_to(reverse_coordinates_,RIGHT))
#         self.play(reverse_.animate.align_to([-6,0,0],UP))
#         self.wait()
#
#         self.wait()
# Out:
# <video src="media\jupyter\Intro@2023-09-13@06-46-11.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

# %%
# %%manim -qm -v WARNING Intro
#
#
# class Intro(Scene):
#     def construct(self):
#         circ = Circle(radius=3, color=WHITE)
#         sqr = Square()
#         numberplane = NumberPlane()
#         equation = MathTex("x^2+y^2=r^2")
#         diameter_signifier = Line(start=[0, 0, 0], end=[3, 0, 0])
#
#         self.play(
#             Write(equation)
#         )
#         self.play(equation.animate.move_to((3*UP+5*RIGHT)), run_time=2)
#         self.wait()
#         self.play(Create(diameter_signifier))
#         radius_text = MathTex("r")
#         self.play(Write(radius_text.move_to([1.5, -0.2, 0])))
#         self.play(Rotate(VGroup(diameter_signifier, radius_text), 2*PI,
#                   about_point=[0, 0, 0], run_time=2), Create(circ), run_time=2)
#
#         # chaine kura ho
#         self.wait()
#
# # class Triangle_rendering(Scene):
# #     def construct(self):
#         angular = PI/180 * 25
#         vertices_sin = [
#             np.array([0, 0, 0]),
#             np.array([3*np.cos(angular), 3*np.sin(angular), 0]),
#             np.array([3*np.cos(angular), 0, 0]),
#         ]
#
#
#         radius_tan = 3/np.cos(angular)
#         vertices_tan = [
#             np.array([0, 0, 0]),
#             np.array([radius_tan*np.cos(angular),
#                      radius_tan*np.sin(angular), 0]),
#             np.array([3, 0, 0]),
#
#         ]
#
#         self.play(FadeOut(radius_text))
#         triangle_sin = Polygon(*vertices_sin, color=BLUE)
#         triangle_tan = Polygon(*vertices_tan, color=GREEN)
#
#         alpha_signifier = ArcBetweenPoints(start=[0.5, 0, 0], end=[
#                                            0.5, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         theta_signifier = ArcBetweenPoints(
#             start=[0.5, 0, 0], end=[0.50, np.tan(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(triangle_sin), run_time=3)
#
#         self.play(Create(triangle_tan), run_time=3)
#         self.play(Create(theta_signifier))
#         self.play(Create(alpha_signifier))
#         theta=MathTex(r"\theta")
#         theta_=MathTex(r"\theta")
#         theta.font_size=30
#         theta_.font_size=30
#         self.add(theta.next_to(theta_signifier,RIGHT,buff=0.1)),
#         self.add(theta_.next_to(alpha_signifier,RIGHT,buff=0.1))
#
#
#         self.wait()
#         together = VGroup(triangle_sin, circ, diameter_signifier,
#                           triangle_tan, alpha_signifier, theta_signifier,theta,theta_)
#         tan_group= VGroup(triangle_tan,alpha_signifier,theta_)
#         self.play(together.animate.move_to(3*LEFT))
#         # self.play((lines.animate.move_to(5*RIGHT+2*UP)))
#         self.wait()
#
#
#         vertices_sin_copy=Line(start=[-3,0,0],end=[np.cos(angular)*3-3,0,0],color=BLUE)
#         self.add(vertices_sin_copy)
#         self.play(tan_group.animate.rotate(-PI,about_point=[-3,0,0]))
#         self.wait()
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)-3, 0, 0], end=[3*np.sin(angular)-3, 0, 0])
#         vertices_sin_c = Line(start=[3*np.sin(angular)-3, 0, 0], end=[-3, 0, 0])
#
#
#
#         self.play(FadeOut(vertices_sin_copy))
#
# #-----------------------------------------------------------------------
#         important=Brace(vertices_sin_a,sharpness=2,direction=(vertices_sin_a.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important))
#         important_text=important.get_tex("r")
#         self.play(Write(important_text))
#         sin_=VGroup(triangle_sin,theta_signifier,theta,important,important_text)
#         self.play(sin_.animate.move_to(5*RIGHT+1.5*UP))
#         tex_1=MathTex(r"sin(\theta)=P_1/H")
#         tex_2=MathTex(r"Hsin(\theta)=P_1")
#         tex_3=MathTex(r"P_1=rsin(\theta)")
#         tex_4=MathTex(r"P_1")
#         self.play(Write(
#         tex_1.next_to(triangle_sin,DOWN),))
#         self.wait()
#         self.play(Write(tex_2.next_to(tex_1,DOWN)))
#         self.wait()
#         self.play(Write(tex_3.next_to(tex_2,DOWN)))
#         self.wait()
#
#         vertices_sin_a = Line(start=[-3, 0, 0], end=[
#                               3*np.cos(angular)-3, 3*np.sin(angular), 0])
#         vertices_sin_b = Line(
#             start=[3*np.cos(angular)+7-3,0.5, 0], end=[3*np.cos(angular)+7-3, 3*np.sin(angular)+0.5, 0])
#         vertices_sin_c = Line(start=[-3*np.sin(angular)+3, 0, 0], end=[-3, 0, 0])
#
#         self.play(
#             FadeOut(tex_1),
#             FadeOut(tex_2)),
#         self.play(tex_3.animate.next_to(triangle_sin,DOWN))
#         self.wait()
#         self.play(sin_.animate.move_to(2*RIGHT+1.5*UP))
#
#         important1=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(-PI/2).get_unit_vector()))
#         self.play(important1.animate.next_to(triangle_sin,RIGHT))
#         self.play(tex_3.animate.next_to(important1,RIGHT))
#         self.wait()
#
#         reverse=VGroup(triangle_sin,theta,theta_signifier,important,important_text,important1,tex_3)
#         reverse_coordinates=[-PI,0,0]
#         self.play(reverse.animate.align_to(reverse_coordinates,LEFT))
#         self.play(reverse.animate.align_to([-3,0,0],DOWN))
#         self.wait()
# # np.array([0, 0, 0]),
# #             np.array([radius_tan*np.cos(angular),
# #                      radius_tan*np.sin(angular), 0]),
# #             np.array([3, 0, 0]),
#
# #             vertices_tan_a=Line(start=[-3,0,0],end=[radius_tan*np.cos(angular)-3,]
#
#
#         self.play(FadeOut(important,important_text))
#
#         radius_tan_ez=Line(start=[-3,0,0],end=[-6,0,0])
#         important_tan=Brace(radius_tan_ez,sharpness=1,direction=(radius_tan_ez.copy().rotate(-PI/2).get_unit_vector()))
#         important_tan_text=important_tan.get_tex("r")
#         self.play(FadeOut(tex_3),
#         tex_4.animate.next_to(important1,RIGHT,buff=0.3)
#         )
#         self.play(Create(important_tan))
#         self.play(Write(important_tan_text))
#         self.wait()
#
#
#
#         tan_group_=VGroup(triangle_tan,alpha_signifier,theta_,important_tan,important_tan_text)
#         self.play(tan_group_.animate.move_to(5*RIGHT+1.2*UP))
#
#         tex_1_=MathTex(r"tan(\theta)=P_2/B")
#         tex_2_=MathTex(r"Btan(\theta)=P_2")
#         tex_3_=MathTex(r"P_2=rtan(\theta)",font_size=40)
#         tex_4_=MathTex(r"P_2",font_size=40)
#         self.play(Write(
#         tex_1_.next_to(triangle_tan,DOWN),))
#         self.wait()
#         self.play(Write(tex_2_.next_to(tex_1_,DOWN)))
#         self.wait()
#         self.play(Write(tex_3_.next_to(tex_2_,DOWN)))
#         self.wait()
#         important_tan_=Brace(vertices_sin_b,sharpness=1,direction=(vertices_sin_b.copy().rotate(PI/2).get_unit_vector()))
#         self.play(Create(important_tan_.next_to(triangle_tan,LEFT)))
#         self.play(
#             FadeOut(tex_1_),
#             FadeOut(tex_2_),
#             tex_3_.animate.next_to(triangle_tan,DOWN),
#             FadeOut(important_tan),
#             FadeOut(important_tan_text)
#         )
#         self.play(tex_3_.animate.next_to(important_tan_,LEFT))
#         reverse_=VGroup(triangle_tan,theta_,alpha_signifier,important_tan_,tex_4_)
#         self.play(FadeOut(tex_3_),
#         tex_4_.animate.next_to(important_tan_,LEFT,buff=0.2)
#         )
#         reverse_coordinates_=[-3,0,0]
#         self.play(reverse_.animate.align_to(reverse_coordinates_,RIGHT))
#         self.play(reverse_.animate.align_to([-6,0,0],UP))
#         self.wait()
#
#         self.wait()
#
#         final_tex=MathTex(r"P_1",font_size=35)
#         final_tex_=MathTex(r"p_2",font_size=35)
#
#         final=VGroup(tex_4_,important_tan_)
#         final_=VGroup(tex_4,important1)
#         self.play(FadeOut(final),
#                  FadeOut(final_)
#         )
#         self.play(tan_group.animate.rotate(PI,about_point=[-3,0,0]),run_time=3)
#         self.play(FadeOut(alpha_signifier,theta_))
#         important_signifier = ArcBetweenPoints(
#             start=[0, 0, 0], end=[3*np.cos(angular)-3,3*np.sin(angular), 0], angle=angular, radius=3)
#         line_important=Line(start=[3*np.cos(angular)-3,0,0],end=[3*np.cos(angular)-3,3*np.sin(angular),0],color=BLUE)
#         line_important_=Line(start=[0,0,0],end=[radius_tan*np.cos(angular)-3,radius_tan*np.sin(angular), 0],color=GREEN)
#         important_group=VGroup(important_signifier,line_important,line_important_)
#         ggez=VGroup(triangle_tan,line_important_)
#
#         self.play(ggez.animate.move_to(3*RIGHT))
#         self.play(FadeOut(triangle_tan))
#         self.play(line_important_.animate.rotate(PI/2))
#         self.play(Write(tex_4_.next_to(line_important_,DOWN)))
#         tex_3_=MathTex(r"P_2=rtan(\theta)",font_size=40)
#         self.play(Write(tex_3_.next_to(tex_4_,DOWN)))
#
#         imp_group=VGroup(line_important_,tex_3_,tex_4_)
#         self.play(imp_group.animate.move_to(2*RIGHT+1*UP))
#
#
#         important_group_1=VGroup(line_important,triangle_sin,theta,theta_signifier)
#         self.play(important_group_1.animate.move_to(3*RIGHT))
#         self.play(FadeOut(triangle_sin),
#         FadeOut(theta),
#         FadeOut(theta_signifier))
#
#         self.play(line_important.animate.rotate(PI/2))
#         self.play(Write(tex_4.next_to(line_important,DOWN)))
#         self.play(Write(tex_3.next_to(tex_4,DOWN)))
#         imp_group_=VGroup(tex_4,tex_3,line_important)
#         self.play(imp_group_.animate.move_to(1*UP+5*RIGHT))
#         line_imp=Line(start=[-3,0,0],end=[3*np.cos(angular)-3,3*np.sin(angular),0])
#         self.play(Create(line_imp))
#
#         last_group=VGroup(diameter_signifier,line_imp,important_signifier)
#         self.play(last_group.animate.move_to(4*RIGHT+1*DOWN))
#         self.play(
#             FadeOut(diameter_signifier),
#             FadeOut(line_imp)
#         )
#
#         self.play(important_signifier.animate.rotate(-PI/2))
#         r_text=MathTex(r"S=r\theta")
#         self.play(Write(r_text.next_to(important_signifier,DOWN,buff=0.5))
#         )
#
#         self.play(important_signifier.animate.set_fill(RED))
#         important_signifier.color=RED
#         self.play(FadeOut(circ))
#         tan_=Line(start=[-3,0,0],end=[radius_tan*np.cos(angular)-3,
#                      radius_tan*np.sin(angular), 0])
#
#         tex_imp=MathTex(r"S")
#         self.play(FadeOut(r_text))
#         self.play(tex_imp.animate.next_to(important_signifier,DOWN,buff=0.5)
#         )
#
#         self.play(triangle_tan.animate.move_to(3*LEFT))
#         self.play(triangle_tan.animate.align_to([-3,0,0],DOWN))
#         self.play(
#             FadeOut(tex_3),
#             FadeOut(tex_3_),
#
#         )
#
#         # tex_3=MathTex(r"P_2",font_size)
#         tan_0=VGroup(line_important_,tex_4_)
#         sin_0=VGroup(line_important,tex_4)
#         arc_0=VGroup(important_signifier,tex_imp)
#
#         self.play(tan_0.animate.rotate(PI/2))
#         self.play(tan_0.animate.next_to(triangle_tan,RIGHT,buff=0))
#
#
#         self.play(sin_0.animate.rotate(PI/2))
#
#         self.play(sin_0.animate.move_to([PI*np.sin(angular)-2.8,0,0]))
#         self.play(sin_0.animate.align_to([np.cos(angular)-3,0,0],DOWN))
#
#         self.play(tex_4.animate.next_to(line_important,LEFT))
#         self.play(important_signifier.animate.move_to([PI*np.sin(angular)-2.8,0,0]))
#         self.play(important_signifier.animate.align_to([np.cos(angular)-3,0,0],DOWN))
#         starting_coords=[3*np.cos(angular)-4.5,0,0]
#         ending_coords=[3*np.cos(angular)-4.5,3*np.sin(angular),0]
#         arc_important=ArcBetweenPoints(starting_coords,ending_coords,radius=3,color=RED)
#         self.play(FadeOut(tex_imp))
#         self.play(Transform(important_signifier,arc_important))
#
#         alpha_signifier2 = ArcBetweenPoints(start=[-4, 0, 0], end=[
#                                            -4, np.sin(angular)*0.5, 0], angle=angular, radius=0.3)
#         self.play(Create(alpha_signifier2))
#         self.add(theta.next_to(alpha_signifier2,RIGHT,buff=0.1))
#         mega=VGroup(alpha_signifier2,theta,triangle_tan,arc_important,tex_4,tex_4_,line_important,line_important_)
#         self.play(mega.animate.move_to(0*RIGHT+0*LEFT+0*UP+0*DOWN))
#         self.play(important_signifier.animate.move_to(3*UP+4*LEFT))
#         self.play(important_signifier.animate.rotate(PI/2))
#         noob=ArcBrace(important_signifier)
#         noob_=MathTex(r"S=r\theta",font_size=35)
#         noob_tex=Tex("Remember that",font_size=35)
#         order=MathTex(r"P_1=r(sin(\theta))",font_size=35)
#         order1=MathTex(r"P_2=r(tan(\theta))",font_size=35)
#         lmao=Tex("Only in radians",font_size=30)
#         self.play(Write(noob_.next_to(important_signifier,DOWN)))
#         self.play(Write(noob_tex.next_to(noob_,DOWN)))
#         lmao.next_to(noob_,RIGHT)
#         self.play(Write(lmao))
#         lmaoggez=SurroundingRectangle(lmao,buff=0.1)
#         self.play(Create(lmaoggez))
#         self.play(Write(order.next_to(noob_tex,DOWN)))
#         self.play(Write(order1.next_to(order,DOWN)))
#         self.play((ScaleInPlace(mega,2)))
#
#
#         a=line_important.get_start()
#         a_=line_important.get_end()
#
#         b=line_important_.get_start()
#         b_=line_important_.get_end()
#
#         c=arc_important.get_start()
#         c_=arc_important.get_end()
#
#         self.play(mega.animate.move_to(0*LEFT+0*RIGHT+0*UP+0*DOWN))
#         self.play(mega.animate.align_to([-4,-2,0],LEFT))
#         self.play(mega.animate.align_to([0,-2,0],DOWN))
#         mega_fuck=VGroup(theta)
#         self.play(Transform(tex_4,order))
#         self.play(Transform(tex_4_,order1))
#         self.play(FadeOut(mega_fuck))
#         dancing=VGroup(tex_4,tex_4_)
#         self.play(FadeOut(dancing))
#         self.play(line_important.animate.rotate(PI/2).next_to((order),RIGHT))
#         self.play(line_important_.animate.rotate(PI/2).next_to((order1),RIGHT))
#         text_imp=MathTex("=")
#         self.play(FadeOut(triangle_tan,alpha_signifier2,arc_important))
#         self.play(FadeOut(equation))
#         lmao=Tex(r"Since all of the terms P1,P2 and S contains r, lets just eliminate r since later, we are going to be compairing all these.",font_size=35)
#         lmao.move_to(2*DOWN)
#         self.play(Write(lmao))
#         self.wait(1.5)
#         self.play(FadeOut(lmao))
#
#         noob_1=MathTex(r"S=\theta",font_size=35)
#         noob_1.next_to(important_signifier,DOWN)
#         order_1=MathTex(r"P_1=sin(\theta)",font_size=35)
#         order_1.next_to(noob_tex,DOWN)
#         order1_1=MathTex(r"P_2=tan(\theta)",font_size=35)
#         order1_1.next_to(order,DOWN)
#         self.play(Transform(noob_,noob_1))
#         self.play(Transform(order,order_1))
#         self.play(Transform(order1,order1_1))
#
#         ez=Tex(r"Let's Decrease the angle").move_to(3*RIGHT+3*UP)
#         self.play(Write(ez))
#
#
#
#         # Initial value of angular
#         angular_tracker = ValueTracker(25)
#
#         # Create DecimalNumber to display angular
#
#
#         # Animate the position of the angular display
#
#         # Add a label for the angular display
#
#
#         tan_display = DecimalNumber(np.tan(np.radians(angular_tracker.get_value())), num_decimal_places=2)
#         sin_display = DecimalNumber(np.sin(np.radians(angular_tracker.get_value())), num_decimal_places=2)
#
# # Add updaters to continuously update tan and sin values
#         tan_display.add_updater(lambda d: d.set_value(np.tan(np.radians(angular_tracker.get_value()))))
#         sin_display.add_updater(lambda d: d.set_value(np.sin(np.radians(angular_tracker.get_value()))))
#         angular_display = DecimalNumber(angular_tracker.get_value(), num_decimal_places=2)
#         angular_display.add_updater(lambda d: d.set_value(angular_tracker.get_value()))
#
# # Position and add the displays to the scene
#         angular_display.next_to(ez,DOWN)
#         angular_label = MathTex(r"\theta =").next_to(angular_display, LEFT)
#         sin_display=sin_display.next_to(angular_display,DOWN)
#         tan_display=tan_display.next_to(sin_display,DOWN)
#         tan_label = MathTex(r"\tan(\theta) =").next_to(tan_display, LEFT)
#         sin_label = MathTex(r"\sin(\theta) =").next_to(sin_display, LEFT)
#
#
#
#         ezDemon1=VGroup(angular_display,angular_label)
#
#         self.play(Write(angular_label))
#         self.play(Write(angular_display))
#
#         self.play(Write(sin_label))
#         self.play(Write(sin_display))
#
#         self.play(Write(tan_label))
#         self.play(Write(tan_display))
#
#
#
#
#
#
#
#
#
#
#
#
#         self.wait(2)
#
#         # Create initial shapes
#         triangle_tan_1 = self.create_triangle_tan(angular_tracker.get_value())
#         triangle_sin_1 = self.create_triangle_sin(angular_tracker.get_value())
#         arc_sin_1 = self.create_arc_sin(angular_tracker.get_value())
#
#         # Add the shapes and the angular display to the scene
#         self.play(Create(triangle_tan_1))
#         self.play(Create (triangle_sin_1))
#         self.play(Create( arc_sin_1))
#         self.play(Create(angular_display))
#
#         # Animation to continuously update shapes
#         self.play(
#             angular_tracker.animate.set_value(0),
#             UpdateFromFunc(triangle_tan_1, lambda mob: mob.become(self.create_triangle_tan(angular_tracker.get_value()))),
#             UpdateFromFunc(triangle_sin_1, lambda mob: mob.become(self.create_triangle_sin(angular_tracker.get_value()))),
#             UpdateFromFunc(arc_sin_1, lambda mob: mob.become(self.create_arc_sin(angular_tracker.get_value()))),
#             run_time=7,
#             rate_func=linear,
#         )
#
#
#
#     def create_triangle_tan(self, angular):
#         starting_co_tan = [
#             np.array([-4, -2, 0]),                # constant
#             np.array([2, -2, 0]),                 # constant
#             np.array([2, 6 * np.tan(np.radians(angular)) - 2, 0])
#         ]
#         return Polygon(*starting_co_tan, color=GREEN)
#
#     def create_triangle_sin(self, angular):
#         starting_co_sin = [
#             np.array([-4, -2, 0]),                # constant
#             np.array([1.437, -2, 0]),             # constant
#             np.array([1.437, 6 * np.sin(np.radians(angular)) - 2, 0])
#         ]
#         return Polygon(*starting_co_sin, color=BLUE)
#
#     def create_arc_sin(self, angular):
#         arc_starting = [1.437, - 2, 0]
#         arc_end = [1.437, 6 * np.sin(np.radians(angular))-2, 0]
#         return ArcBetweenPoints(start=arc_starting, end=arc_end, angle=np.radians(angular), radius=6)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         self.wait(2)
# Out:
# <video src="media\jupyter\Intro@2023-10-17@09-07-21.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm -v WARNING Second
#
# class Second(Scene):
#     def construct(self):
#         ez1 = Tex("Observe Closely")
#         self.play(Write(ez1))
#         self.wait(2)
#         self.play(FadeOut(ez1))
#
#         angular_tracker = ValueTracker(25)
#
#         # Create DecimalNumber to display angular
#         angular_display = DecimalNumber(angular_tracker.get_value(), num_decimal_places=2)
#         angular_display.add_updater(lambda d: d.set_value(angular_tracker.get_value()))
#
#         # Add a label for the angular display
#         angular_label = MathTex(r"S=\theta =").next_to(angular_display, LEFT)
#         ezDemon1 = VGroup(angular_display, angular_label)
#
#         tan_display = DecimalNumber(np.tan(np.radians(angular_tracker.get_value())), num_decimal_places=5)
#         sin_display = DecimalNumber(np.sin(np.radians(angular_tracker.get_value())), num_decimal_places=5)
#
#         # Add updaters to continuously update tan and sin values
#         tan_display.add_updater(lambda d: d.set_value(np.tan(np.radians(angular_tracker.get_value()))))
#         sin_display.add_updater(lambda d: d.set_value(np.sin(np.radians(angular_tracker.get_value()))))
#
#         # Position and add the displays to the scene
#         angular_label = angular_label.move_to(3 * RIGHT + 3 * UP)
#         angular_display = angular_display.next_to(angular_label, RIGHT)
#         sin_label=MathTex(r"\sin(\theta) =").next_to(angular_label, DOWN)
#         sin_display = sin_display.next_to(sin_label, RIGHT)
#         tan_label = MathTex(r"\tan(\theta) =").next_to(sin_label, DOWN)
#         tan_display = tan_display.next_to(tan_label, RIGHT)
#
#
#
#         self.play(Write(angular_label))
#         self.play(Write(angular_display))
#
#         self.play(Write(sin_label))
#         self.play(Write(sin_display))
#         self.play(Write(tan_label))
#         self.play(Write(tan_display))
#
#         self.wait(2)
#
#         # Create initial shapes
#         triangle_tan_1 = self.create_triangle_tan(angular_tracker.get_value())
#         triangle_sin_1 = self.create_triangle_sin(angular_tracker.get_value())
#         arc_sin_1 = self.create_arc_sin(angular_tracker.get_value())
#
#         # Add the shapes and the angular display to the scene
#         self.play(Create(triangle_tan_1))
#         self.play(Create(triangle_sin_1))
#         self.play(Create(arc_sin_1))
#         self.play(Create(angular_display))
#
#         # Animation to continuously update shapes
#         self.play(
#             angular_tracker.animate.set_value(0),
#             UpdateFromFunc(triangle_tan_1, lambda mob: mob.become(self.create_triangle_tan(angular_tracker.get_value()))),
#             UpdateFromFunc(triangle_sin_1, lambda mob: mob.become(self.create_triangle_sin(angular_tracker.get_value()))),
#             UpdateFromFunc(arc_sin_1, lambda mob: mob.become(self.create_arc_sin(angular_tracker.get_value()))),
#             run_time=10,
#             rate_func=linear,
#         )
#
#         # Code defined within construct(self) is executed here
#         self.wait(3)
#         ez3 = MathTex(r"\theta")
#         self.add(ez3)
#
#     def create_triangle_tan(self, angular):
#         starting_co_tan = [
#             np.array([-4, -2, 0]),  # constant
#             np.array([2, -2, 0]),  # constant
#             np.array([2, 6 * np.tan(np.radians(angular)) - 2, 0])
#         ]
#         return Polygon(*starting_co_tan, color=GREEN)
#
#     def create_triangle_sin(self, angular):
#         starting_co_sin = [
#             np.array([-4, -2, 0]),  # constant
#             np.array([1.437, -2, 0]),  # constant
#             np.array([1.437, 6 * np.sin(np.radians(angular)) - 2, 0])
#         ]
#         return Polygon(*starting_co_sin, color=BLUE)
#
#     def create_arc_sin(self, angular):
#         arc_starting = [1.437, - 2, 0]
#         arc_end = [1.437, 6 * np.sin(np.radians(angular)) - 2, 0]
#         return ArcBetweenPoints(start=arc_starting, end=arc_end, angle=np.radians(angular), radius=6)
# Out:
# <video src="media\jupyter\Second@2023-10-17@08-32-27.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING second_two
# class second_two(Scene):
#     def construct(self):
#         ggez = MathTex(r"\theta")
#         lmao = MathTex("P_1")
#         lmao2 = MathTex("P_2")
#
#         text = Tex("It is pretty apparent that at nearly all points, value of (Blue Line) is less than the value of S (arc length) which is less than the value of (green line)", font_size=35)
#
#         self.play(Write(text))
#         self.wait()
# Out:
# <video src="media\jupyter\second_two@2023-10-17@08-41-38.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING third
# class third(Scene):
#     def construct(self):
#
#
#         text = Tex("It is pretty apparent that at nearly all points, value of (Blue Line) is less than the value of S (arc length) which is less than the value of (green line)", font_size=35)
#         text.move_to(2*UP)
#         self.play(Write(text))
#         self.wait(1)
#
#         text_=Tex("From that observation the conclusion required can be derived, but for the sake of causality",font_size=35)
#         text_.next_to(text,DOWN)
#         self.play(Write(text_))
#         self.wait(2)
#
#         w=Tex("Lets look at the different values at 4 random instances in the previous scene",font_size=35)
#         w.next_to(text_,DOWN)
#         self.play(Write(w))
#         self.wait(1.5)
#         self.play(FadeOut(w))
#         self.play(FadeOut(text_))
#         self.play(FadeOut(text))
#         w1=MathTex(r"\theta(Radian)")
#         w2=MathTex(r"sin(\theta)")
#         w3=MathTex(r"tan(\theta)")
#         w_4=MathTex(r"\theta(Degree)")
#         t_0=MathTable(
#             [[25,0.436,0.422,0.466],
#             [18.67,0.325,0.320,0.337],
#             [7.58,0.132,0.131,0.133],
#             [0,0,0,0]],
#         col_labels=[w_4,w1,w2,w3]
#         )
#         self.add((t_0))
#         self.wait(5)
#         g1=Group(t_0)
#         self.play(ScaleInPlace(g1,0.5))
#         self.play(g1.animate.to_edge(UP))
#
#         w_1=Tex("From the table we conclude that:")
#         self.play(Write(w_1))
#         self.wait()
#         self.play(w_1.animate.next_to(t_0,DOWN))
#         w_2=MathTex(r"sin(\theta)\leq\theta\leq tan(\theta)")
#         w_2=w_2.next_to(w_1,DOWN)
#         self.play(Write(w_2))
#         w_fuck=Tex(r"Only When Theta is measured in radians")
#         w_fuck.next_to(w_2,DOWN)
#         w_fuckbox=SurroundingRectangle(w_fuck,buff=0.1)
#         self.play(Write(w_fuck))
#         self.play(Create(w_fuckbox))
#         self.wait(2)
# Out:
# <video src="media\jupyter\third@2023-10-17@08-54-57.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING fourth
# class fourth(Scene):
#     def construct(self):
#         w_2=MathTex(r"sin(\theta)\leq\theta\leq tan(\theta),",font_size=40)
#         w_2.to_edge(UP)
#         self.play(Write(w_2))
#         self.wait(2)
#         w_fuck_=MathTex(r"\theta=\quad radian",font_size=40)
#         w_fuck_.next_to(w_2,RIGHT,buff=0.5)
#         self.play(Write(w_fuck_))
#         self.wait()
#         w_fuck_box=SurroundingRectangle(w_fuck_,buff=0.1)
#         self.play(Create(w_fuck_box))
#         w_3=MathTex(r"\frac{1}{sin(\theta)} \geq \frac{1}{\theta} \geq \frac{1}{tan(\theta)}",font_size=40)
#         w_3.next_to(w_2,DOWN)
#         w_4=Tex("Since inversing terms in an equality changes the equality sign")
#         self.play(Write(w_3))
#         w_4.next_to(w_3,DOWN)
#         self.play(Write(w_4))
#         self.wait(2)
#         self.play(FadeOut(w_4))
#         w_5=MathTex(r"Multiplying \quad by \quad sin(\theta)\quad in \quad all \quad sides. ")
#         self.play(Write(w_5))
#         self.wait(1.5)
#         w_6=MathTex(r"\frac{sin(\theta)}{sin(\theta)} \geq \frac{sin(\theta)}{\theta} \geq \frac{sin(\theta)}{tan(\theta)}",font_size=40)
#         w_6.next_to(w_5,DOWN)
#         self.play(Write(w_6))
#         self.wait()
#         self.play(FadeOut(w_5))
#         self.play(w_6.animate.next_to(w_3,DOWN))
#         self.wait()
#         w2_7=MathTex(r"1 \geq\frac{sin(\theta)}{\theta}\geq\frac{sin(\theta)}{tan(\theta)}",font_size=40)
#         w2_7.next_to(w_6,DOWN)
#         self.play(Write(w2_7))
#         w2_8=MathTex(r"Since, \quad tan(\theta)=\frac{sin(\theta)}{cos(\theta)}",font_size=40)
#         w2_8.next_to(w2_7,DOWN)
#         self.play(Write(w2_8))
#         self.wait(1.5)
#         self.play(FadeOut(w2_8))
#         w2_9=MathTex(r"1\geq \frac{sin(\theta)}{\theta}\geq cos(\theta)",font_size=40)
#         w2_9.next_to(w2_7,DOWN)
#         self.play(Write(w2_9))
#         self.wait()
#         fade_group=VGroup(w_3,w_6,w2_7)
#         self.play(FadeOut(fade_group))
#         self.play(w2_9.animate.next_to(w_2,DOWN))
#         w2_10=Tex(r"Taking limit as x approaches 0 in all sides")
#         w2_10.next_to(w2_9,DOWN)
#         self.play(Write(w2_10))
#         w2_11=MathTex(r"\lim_{\theta\to0} 1 \geq \lim_{\theta\to0} \frac{sin(\theta)}{\theta} \geq \lim_{\theta\to0} cos(\theta)")
#         w2_11.next_to(w2_10,DOWN)
#         self.play(Write(w2_11))
#         self.wait()
#         w_main=MathTex(r"1 \geq \lim_{\theta\to0}\frac{sin(\theta)}{\theta} \geq 1")
#         w_main.next_to(w2_11,DOWN)
#         self.play(Write(w_main))
#         mega_fuck_=Group(w2_9,w2_10,w2_11)
#         self.play(FadeOut(mega_fuck_))
#         self.play(w_main.animate.next_to(w_2,DOWN))
#         self.wait(2)
#         w_main_=Tex("What this means, is when x approaches 0 in (sin(x)/(x) the limit is either less than or equal to 1 but it is also greater than or equal to 1. Both this statement are only true when the limit is 1. Meaning," ,font_size=40 )
#         self.play(Write(w_main_))
#         self.wait()
#         w_final=MathTex(r"\lim_{\theta\to0}\frac{sin(\theta)}{\theta}     =    1")
#         w_final.next_to(w_main_,DOWN)
#         self.play(Write(w_final))
#         frame_=SurroundingRectangle(w_final,buff=0.1)
#         self.play(Create(frame_))
#         remarks=Tex("Adish",font_size=35)
#         remarks.to_edge(LEFT)
#         remarks.to_edge(DOWN)
#         self.play(Write(remarks))
#         self.wait(5)
# Out:
# <video src="media\jupyter\fourth@2023-09-15@19-10-45.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
# Out:
# Manim Community v0.17.3
